# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/vehicles.csv')
df.head()
# Out:
#            id                                                url  \
# 0  7222695916  https://prescott.craigslist.org/cto/d/prescott...
# 1  7218891961  https://fayar.craigslist.org/ctd/d/bentonville...
# 2  7221797935  https://keys.craigslist.org/cto/d/summerland-k...
# 3  7222270760  https://worcester.craigslist.org/cto/d/west-br...
# 4  7210384030  https://greensboro.craigslist.org/cto/d/trinit...
#
#                    region                         region_url  price  year  \
# 0                prescott    https://prescott.craigslist.org   6000   NaN
# 1            fayetteville       https://fayar.craigslist.org  11900   NaN
# 2            florida keys        https://keys.craigslist.org  21000   NaN
# 3  worcester / central MA   https://worcester.craigslist.org   1500   NaN
# 4              greensboro  https://greensboro.craigslist.org   4900   NaN
#
#   manufacturer model condition cylinders  ... size  type paint_color  \
# 0          NaN   NaN       NaN       NaN  ...  NaN   NaN         NaN
# 1          NaN   NaN       NaN       NaN  ...  NaN   NaN         NaN
# 2          NaN   NaN       NaN       NaN  ...  NaN   NaN         NaN
# 3          NaN   NaN       NaN       NaN  ...  NaN   NaN         NaN
# 4          NaN   NaN       NaN       NaN  ...  NaN   NaN         NaN
#
#   image_url description county state lat long posting_date
# 0       NaN         NaN    NaN    az NaN  NaN          NaN
# 1       NaN         NaN    NaN    ar NaN  NaN          NaN
# 2       NaN         NaN    NaN    fl NaN  NaN          NaN
# 3       NaN         NaN    NaN    ma NaN  NaN          NaN
# 4       NaN         NaN    NaN    nc NaN  NaN          NaN
#
# [5 rows x 26 columns]

# %%
df.isnull().sum()
# Out:
# id                   0
# url                  0
# region               0
# region_url           0
# price                0
# year              1205
# manufacturer     17646
# model             5277
# condition       174104
# cylinders       177678
# fuel              3013
# odometer          4400
# title_status      8242
# transmission      2556
# VIN             161042
# drive           130567
# size            306361
# type             92858
# paint_color     130203
# image_url           68
# description         70
# county          426880
# state                0
# lat               6549
# long              6549
# posting_date        68
# dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'url', 'region', 'region_url', 'price', 'year', 'manufacturer',
#        'model', 'condition', 'cylinders', 'fuel', 'odometer', 'title_status',
#        'transmission', 'VIN', 'drive', 'size', 'type', 'paint_color',
#        'image_url', 'description', 'county', 'state', 'lat', 'long',
#        'posting_date'],
#       dtype='object')

# %%
df.condition.value_counts()
# Out:
# condition
# good         121456
# excellent    101467
# like new      21178
# fair           6769
# new            1305
# salvage         601
# Name: count, dtype: int64

# %%
df.drop(df[df.condition.isin(['new','salvage'])].index, inplace=True)

# %%
df = df[df['odometer'].notna()]

# %%
df_spec = pd.read_csv('data/USA_cars_datasets.csv')
df_spec.head()
# Out:
#    Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0           0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1           1   2899       ford       se  2011  clean vehicle  190552.0
# 2           2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3           3  25000       ford     door  2014  clean vehicle   64146.0
# 4           4  27700  chevrolet     1500  2018  clean vehicle    6654.0
#
#     color                  vin        lot       state country      condition
# 0   black    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1  silver    2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2  silver    3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3    blue    1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# 4     red    3gcpcrec2jg473991  167763266     florida     usa  22 hours left

# %%
df_spec.columns
# Out:
# Index(['Unnamed: 0', 'price', 'brand', 'model', 'year', 'title_status',
#        'mileage', 'color', 'vin', 'lot', 'state', 'country', 'condition'],
#       dtype='object')

# %%
print(f"Earliest posting_date: {df.posting_date.min()} $\Latest posting_date: {df.posting_date.max()} $")
# Out:
# Earliest posting_date: 2021-04-04T00:10:40-0700 $\Latest posting_date: 2021-05-04T23:59:45-0400 $

# %%
print(f"Maximum price: {df.price.max()} $\nMinimum price: {df.price.min()} $")
# Out:
# Maximum price: 3736928711 $
# Minimum price: 0 $

# %%
plt.hist(df.price, bins=50, range=[0,100000])
# Out:
# (array([4.9996e+04, 2.5569e+04, 3.3608e+04, 3.3423e+04, 2.8267e+04,
#         2.1374e+04, 2.1038e+04, 2.1557e+04, 1.9466e+04, 1.8567e+04,
#         1.3196e+04, 1.3557e+04, 1.4641e+04, 1.3619e+04, 1.4208e+04,
#         1.0322e+04, 1.0432e+04, 1.0415e+04, 8.4450e+03, 1.0177e+04,
#         3.8970e+03, 3.6990e+03, 3.2470e+03, 2.3790e+03, 2.7250e+03,
#         1.1860e+03, 1.6220e+03, 1.4670e+03, 8.7800e+02, 1.4710e+03,
#         4.1600e+02, 6.4800e+02, 7.7100e+02, 4.0900e+02, 8.2800e+02,
#         2.6000e+02, 3.4400e+02, 2.9600e+02, 2.0800e+02, 3.7700e+02,
#         9.6000e+01, 1.7300e+02, 1.6900e+02, 1.0900e+02, 1.1800e+02,
#         3.6000e+01, 5.7000e+01, 5.2000e+01, 1.8000e+01, 1.1900e+02]),
#  array([     0.,   2000.,   4000.,   6000.,   8000.,  10000.,  12000.,
#          14000.,  16000.,  18000.,  20000.,  22000.,  24000.,  26000.,
#          28000.,  30000.,  32000.,  34000.,  36000.,  38000.,  40000.,
#          42000.,  44000.,  46000.,  48000.,  50000.,  52000.,  54000.,
#          56000.,  58000.,  60000.,  62000.,  64000.,  66000.,  68000.,
#          70000.,  72000.,  74000.,  76000.,  78000.,  80000.,  82000.,
#          84000.,  86000.,  88000.,  90000.,  92000.,  94000.,  96000.,
#          98000., 100000.]),
#  <BarContainer object of 50 artists>)

# %%
df.drop(df[df.price <= 100].index, inplace = True)

# %%
df.drop(df[df.price > 150000].index, inplace = True)

# %%
plt.hist(df.price, bins=50, range=[0,100000])
# Out:
# (array([1.5969e+04, 2.5569e+04, 3.3608e+04, 3.3423e+04, 2.8267e+04,
#         2.1374e+04, 2.1038e+04, 2.1557e+04, 1.9466e+04, 1.8567e+04,
#         1.3196e+04, 1.3557e+04, 1.4641e+04, 1.3619e+04, 1.4208e+04,
#         1.0322e+04, 1.0432e+04, 1.0415e+04, 8.4450e+03, 1.0177e+04,
#         3.8970e+03, 3.6990e+03, 3.2470e+03, 2.3790e+03, 2.7250e+03,
#         1.1860e+03, 1.6220e+03, 1.4670e+03, 8.7800e+02, 1.4710e+03,
#         4.1600e+02, 6.4800e+02, 7.7100e+02, 4.0900e+02, 8.2800e+02,
#         2.6000e+02, 3.4400e+02, 2.9600e+02, 2.0800e+02, 3.7700e+02,
#         9.6000e+01, 1.7300e+02, 1.6900e+02, 1.0900e+02, 1.1800e+02,
#         3.6000e+01, 5.7000e+01, 5.2000e+01, 1.8000e+01, 1.1900e+02]),
#  array([     0.,   2000.,   4000.,   6000.,   8000.,  10000.,  12000.,
#          14000.,  16000.,  18000.,  20000.,  22000.,  24000.,  26000.,
#          28000.,  30000.,  32000.,  34000.,  36000.,  38000.,  40000.,
#          42000.,  44000.,  46000.,  48000.,  50000.,  52000.,  54000.,
#          56000.,  58000.,  60000.,  62000.,  64000.,  66000.,  68000.,
#          70000.,  72000.,  74000.,  76000.,  78000.,  80000.,  82000.,
#          84000.,  86000.,  88000.,  90000.,  92000.,  94000.,  96000.,
#          98000., 100000.]),
#  <BarContainer object of 50 artists>)

# %%
plt.hist(df.year[df['year'] < 2020])#.describe()
# Out:
# (array([7.00000e+00, 4.70000e+01, 4.06000e+02, 4.70000e+02, 1.33600e+03,
#         3.26900e+03, 3.29500e+03, 7.46300e+03, 7.19920e+04, 2.77804e+05]),
#  array([1900. , 1911.9, 1923.8, 1935.7, 1947.6, 1959.5, 1971.4, 1983.3,
#         1995.2, 2007.1, 2019. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df.year[df['year'] < 1990])#.describe()
# Out:
# (array([   5.,    7.,   69.,  379.,  351.,  692., 1065., 2967., 2624.,
#         3562.]),
#  array([1900. , 1908.9, 1917.8, 1926.7, 1935.6, 1944.5, 1953.4, 1962.3,
#         1971.2, 1980.1, 1989. ]),
#  <BarContainer object of 10 artists>)

# %%
df.drop(df[df.year <= 1940].index, inplace = True)

# %%
df.model[df.manufacturer.isnull()].value_counts()
# Out:
# model
# Scion iM Hatchback 4D             640
# smart fortwo Passion Hatchback    168
# Genesis G80 3.8 Sedan 4D          163
# International 4300                147
# Scion xD Hatchback 4D             134
#                                  ...
# Isuzu NPR FLAT BED                  1
# 2009 SMARFORTWO                     1
# CJ7                                 1
# Setra S417                          1
# 96 Suburban                         1
# Name: count, Length: 5522, dtype: int64

# %%
df.model[df.model.str.upper().str.contains('SCION') & df.manufacturer.isnull()].unique()
# Out:
# array(['Scion iM Hatchback 4D', 'scion ia', 'Scion xD Hatchback 4D',
#        'Scion FR-S', 'Scion tC', 'Scion iQ', 'scion xb', '2008 scion tc',
#        '2012 scion xb', 'Scion FR-S Release Series 2.0',
#        'Scion FR-S Coupe 2D', 'Scion xA', 'Scion XB', 'SCION TC',
#        'scion xd', 'Scion FR-S 10 Series', 'Scion tC Hatchback Coupe 2D',
#        'Scion TC', 'scion fr-s base', 'scion tc', 'scion frs',
#        'scion fr-s', '2007 scion tc', 'Scion xB', 'Scion xD',
#        'Scion tC Base Coupe', 'Scion iA', 'scion tc coupe',
#        'SCION xB Hatchback 4DR', 'Scion XA Manual', 'scion xa',
#        'Scion tC 10 Series', 'scion xd hatchback 4d', 'SCION XB',
#        '2015 scion tc', 'Scion XD', 'scion XD', '2012 scion IQ',
#        'Scion tc', 'SCION/TC', '2011 scion tc', 'Scion xb', 'Scion iM',
#        'Scion IA', '2009 Scion xb', '2006 scion xa', '2008 scion xb',
#        'Scion xB BaseWagon 4A', '2012 SCION XB', 'Scion TC 2.0',
#        'Scion xB 5dr Wgn Auto (Natl)', 'Scion Supercharged TC',
#        'SCION XA', '2013 scion fr-s', 'Toyoya Scion Tc', '2005 scion XA',
#        'Scion tC 2009 release series 5.0', 'Scion xB Base Wagon',
#        'Tyota scion', 'SCION FR-S', 'scion xa 4dr hatchback', 'Scion xd',
#        'Scion TC five speed', 'scion xb automatic', 'SCION FR-S COUPE',
#        'scion', 'Scion xA Hatchback 4D', 'Scion iA Sedan',
#        'Scion tC FWD gas Sedan Manual', '2009 Scion XD', 'SCION XD',
#        'Scion TC Hatchback 2D', 'Scion tC Base 2dr Coupe 6M',
#        'Scion TC Coupe', '2011 Scion tc', 'Scion XB 4dr Wagon',
#        'Scion IQ', 'Scion xD Base', 'Scion XA', '2009 Scion xD',
#        'Scion Tc', 'SCION TC HATCHBACK COUPE 2D', 'scion fr-s coupe',
#        '2006 scion xb', 'SCION TC 2dr HB', 'scion xD',
#        'Scion tC 2dr HB Auto (Natl)', 'scion Tc', 'Scion iA Sedan 4D',
#        '2009 Scion TC', '2014 Scion xb', 'Scion FR-S Monogram',
#        'Scion xB 5dr Wgn Man (Natl)', '2014 SCION FR-S',
#        'scion fr-s coupe 2d', 'scion im hatchback 4d',
#        'Scion xD Base 4dr Hatchback 5M', 'Scion tC Hatchback Coupe',
#        'Scion xA Hatchback', '2006 scion tc',
#        'SCION CT RELEASE SERIES 7.0.AZ10', '2006 Scion tC',
#        'Scion TC 2dr Hatchback', 'SCION tC', 'Scion', '2009 Scion xB',
#        'scion tc release series', 'Scion IA 4 Dr', 'scion iq',
#        '2013 scion frs', 'Scion xB Base', '2009 scion xb', 'SCION iA',
#        'scion xa base 4dr hatchback', 'Scion FRS', '2015 Scion xB Base',
#        'scion tC 2014', '2011 SCION XB', 'Scion XB sport',
#        'SCION TC Base', 'Scion tC Coupe', 'SCION BASE', '2010 Scion XB'],
#       dtype=object)

# %%
cars = list(df_spec.brand.unique())
cars = [x for x in cars if x not in ['heartland', 'land', 'peterbilt', 'ram', 'harley-davidson']]
cars.extend(['scion', 'smart', 'mercedes', 'mercedez', 'chevy', 'pontiac'])
print(cars)
# Out:
# ['toyota', 'ford', 'dodge', 'chevrolet', 'gmc', 'chrysler', 'kia', 'buick', 'infiniti', 'mercedes-benz', 'jeep', 'bmw', 'cadillac', 'hyundai', 'mazda', 'honda', 'jaguar', 'acura', 'audi', 'lincoln', 'lexus', 'nissan', 'maserati', 'scion', 'smart', 'mercedes', 'mercedez', 'chevy']

# %%
car_makers = [x.upper() for x in cars]
car_makers
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 car_makers = [x.upper() for x in cars]
#       2 car_makers
#
# Cell In[111], line 1, in <listcomp>(.0)
# ----> 1 car_makers = [x.upper() for x in cars]
#       2 car_makers
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
df_nomanu = df[df.manufacturer.isnull()].reset_index()
df_manu = df[~df.manufacturer.isnull()].reset_index()
df_nomanu
# Out:
#         index          id                                                url  \
# 0          97  7309271279  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 1         122  7306198330  https://auburn.craigslist.org/cto/d/west-point...
# 2         135  7305150004  https://auburn.craigslist.org/ctd/d/auburn-uni...
#
# 15386  CALL OR TEXT BLAYNE @ 406-450-6788  2017 FORD ...    NaN    wy
# 15387  CALL OR TEXT BLAYNE @ 406-450-6788  2015 FORD ...    NaN    wy
# 15388  Carvana is the safer way to buy a car During t...    NaN    wy
# 15389  Carvana is the safer way to buy a car During t...    NaN    wy
# 15390  Carvana is the safer way to buy a car During t...    NaN    wy
#
#            lat      long              posting_date
# 0      32.5900  -85.4800  2021-04-19T10:51:13-0500
# 1      32.8337  -85.1197  2021-04-13T11:20:25-0500
# 2      32.5900  -85.4800  2021-04-11T10:11:14-0500
# 3      32.4169  -85.7094  2021-04-11T07:07:52-0500
# 4      32.5900  -85.4800  2021-04-06T11:21:37-0500
# ...        ...       ...                       ...
# 15386  48.1783 -111.9397  2021-04-05T10:51:16-0600
# 15387  48.1783 -111.9397  2021-04-05T10:35:07-0600
# 15388  33.7865  -84.4454  2021-04-05T03:10:18-0600
# 15389  33.7865  -84.4454  2021-04-05T02:50:20-0600
# 15390  33.7865  -84.4454  2021-04-04T03:50:17-0600
#
# [15391 rows x 27 columns]

# %%
# Out:
# ['TOYOTA',
#  'FORD',
#  'DODGE',
#  'CHEVROLET',
#  'GMC',
#  'CHRYSLER',
#  'KIA',
#  'BUICK',
#  'INFINITI',
#  'MERCEDES-BENZ',
#  'JEEP',
#  'BMW',
#  'CADILLAC',
#  'HYUNDAI',
#  'MAZDA',
#  'HONDA',
#  'JAGUAR',
#  'ACURA',
#  'AUDI',
#  'LINCOLN',
#  'LEXUS',
#  'NISSAN',
#  'MASERATI']

# %%
'''
for i, j in df_nomanu.iterrows():
    print(i)
    desc = df_nomanu.iloc[i]['description']
    model = df_nomanu.iloc[i]['model']
    #print(desc)

    for yr in stringyears:
        if yr in desc:
            print(yr)
    for brand in car_makers:
        if brand in model.upper():
            print(brand)
    for car in car_makers:
        if car in desc.upper():
            print(car)
    print('\n')
    break
'''
df_nomanu.iloc[0].description
# Out:
# "Carvana is the safer way to buy a car During these uncertain times, Carvana is dedicated to ensuring safety for all of our customers. In addition to our 100% online shopping and selling experience that allows all customers to buy and trade their cars without ever leaving the safety of their house, we’re providing touchless delivery that make all aspects of our process even safer. Now, you can get the car you want, and trade in your old one, while avoiding person-to-person contact with our friendly advocates. There are some things that can’t be put off. And if buying a car is one of them, know that we’re doing everything we can to keep you keep moving while continuing to put your health safety, and happiness first. Vehicle Stock# 2000948207📱 Want to instantly check this car’s availability? Call us at  334-758-9176Just text that stock number to 855-976-4304 or head to  and plug it into the search bar!Get PRE-QUALIFIED for your auto loan in 2 minutes - no hit to your credit:http://finance.carvanaauto.com/7015185-75014Looking for more cars like this one? We have 7 Scion iM in stock for as low as $12990!Why buy with Carvana? We have one standard: the highest. Take a look at just some of the qualifications all of our cars must meet before we list them.150-POINT INSPECTION: We put each vehicle through a 150-point inspection so that you can be 100% confident in its quality and safety. See everything that goes into our inspections at:NO REPORTED ACCIDENTS: We do not sell cars that have been in a reported accident or have a frame or structural damage.7 DAY TEST OWN MONEY BACK GUARANTEE: Every Carvana car comes with a 7-day money-back guarantee. Why? It takes more than 15-minutes to make a decision on your next car. Learn more about test owning at http://about.carvanaauto.comFLEXIBLE FINANCING, TRADE INS WELCOME: We’re all about real-time financing without the middle man. Need financing? Pick a combination of down and monthly payments that work for you. Have a trade-in? We’ll give you a value in 2 minutes. Check out everything about our financing at:http://finance.carvanaauto.com/7015185-75014COST SAVINGS: Carvana's business model has fewer expenses and no bloated fees compared to your local dealership. See how much we can save you at http://about.carvanaauto.comPREMIUM DETAIL: We go the extra mile so that your car is looking as good as new. There are a lot of specifics that we won’t list here (we wash, clean, buff, paint, polish, wax, seal), but trust us that when your car arrives, it’s going to look sweet.Vehicle Info for Stock# 2000948207Trim: Hatchback 4D hatchbackMileage: 29k milesExterior Color: BlueInterior Color: BlackEngine: 1.8L I4 137hp 126ft. lbs.Drive: fwdTransmission: VIN: JTNKARJEXGJ517925Dealer Disclosure: Price excludes tax, title, and registration (which we handle for you).Disclaimer: You agree that by providing your phone number, Carvana, or Carvana’s authorized representatives*, may call and/or send text messages (including by using equipment to automatically dial telephone numbers) about your interest in a purchase, for marketing/sales purposes, or for any other servicing or informational purpose related to your account. You do not have to consent to receiving calls or texts to purchase from Carvana. While every reasonable effort is made to ensure the accuracy of the information for this Scion iM, we are not responsible for any errors or omissions contained in this ad. Please verify any information in question with Carvana at 334-758-9176*Including, but not limited to, Bridgecrest Credit Company, GO Financial and SilverRock Automotive.*Scion* *iM* *Base* *Scion* *iM* *10* *Series* *Scion* *iM* *2dr* *Hatchback* *Scion* *iM* *Sion* *Scion* *iM* *Syon* *Scion* *iM* *Cion* *Scion* *iM* *Cyon* *Scion* *iM* *Toyota* *Scion* *IQ* *Scion* *iM* *Toyota* *Scion* *i* *q* *Scion* *iM* *Toyota* *Scion* *I-Q* *Scion* *iM* *Toyota* *Scion* *I_Q* *Scion* *iM* *Scion* *I_Q* *Scion* *iM* *Scion* *IQ* *Scion* *iM* *Scion* *i* *q* *Sc ...

# %%
df[df.id == 7302129327].description.astype(str)
# Out:
# 426843    CALL OR TEXT BLAYNE @ 406-450-6788  2017 FORD ...
# Name: description, dtype: object

# %%
years = np.arange(1940, 2021)
years
stringyears = np.char.mod('%d', years)
stringyears
pattern = '|'.join(stringyears)
pattern
# Out:
# '1940|1941|1942|1943|1944|1945|1946|1947|1948|1949|1950|1951|1952|1953|1954|1955|1956|1957|1958|1959|1960|1961|1962|1963|1964|1965|1966|1967|1968|1969|1970|1971|1972|1973|1974|1975|1976|1977|1978|1979|1980|1981|1982|1983|1984|1985|1986|1987|1988|1989|1990|1991|1992|1993|1994|1995|1996|1997|1998|1999|2000|2001|2002|2003|2004|2005|2006|2007|2008|2009|2010|2011|2012|2013|2014|2015|2016|2017|2018|2019|2020'

# %%
df_noyear = df[df.year.isnull()].reset_index()
df_year = df[~df.year.isnull()].reset_index()
# 1108          NaN  https://images.craigslist.org/00Y0Y_dj1xAat4S2...
# 1109          NaN  https://images.craigslist.org/00V0V_9TKWxbnlp3...
#
#                                             description county state  \
# 0     2018 *Cadillac* *XT5 Crossover* FWD 4dr Premiu...    NaN    al
# 1     2020 *BMW* *3 Series* 330i Sedan - $35,495Call...    NaN    al
# 2     2018 *Jaguar* *XF* 25t Premium RWD Sedan - $32...    NaN    al
# 3     2018 *Hyundai* *Santa Fe* SE Ultimate 3.3L Aut...    NaN    al
# 4     2018 *Mercedes-Benz* *CLA* CLA 250 4MATIC Coup...    NaN    al
# ...                                                 ...    ...   ...
# 1105  2020 *GMC* *Sierra 3500HD* SLT Truck - $78,580...    NaN    wa
# 1106  2020 *Chevrolet* *Silverado 3500HD CC* 3500HD ...    NaN    wv
# 1107  2020 *Chevrolet* *Silverado MD* 5500HD CREW 4X...    NaN    wv
# 1108  2018 *Honda* *HR-V* LX 6 SPEED MANUAL  SUV - $...    NaN    wi
# 1109  2019 *Jeep* *Renegade* LATITUDE 4WD ONE OWNER ...    NaN    wi
#
#             lat        long              posting_date
# 0     33.669601  -86.817617  2021-05-04T10:11:04-0500
# 1     33.669601  -86.817617  2021-05-01T04:40:22-0500
# 2     33.669601  -86.817617  2021-04-27T10:10:59-0500
# 3     33.669601  -86.817617  2021-04-25T04:40:35-0500
# 4     33.669601  -86.817617  2021-04-24T10:01:21-0500
# ...         ...         ...                       ...
# 1105  47.434493 -120.320759  2021-04-05T07:10:39-0700
# 1106  38.767754  -77.707905  2021-04-12T10:06:31-0400
# 1107  38.767754  -77.707905  2021-04-12T10:05:21-0400
# 1108  43.176636  -88.023648  2021-04-26T11:42:40-0500
# 1109  43.176636  -88.023648  2021-04-26T11:38:41-0500
#
# [1110 rows x 27 columns]

# %%
df_noyear_y = df_noyear[df_noyear.description.str.contains(pattern)]
df_noyear_n = df_noyear[~df_noyear.description.str.contains(pattern)]
df_noyear.shape[0] == (df_noyear_y.shape[0] + df_noyear_n.shape[0])
# Out:
# True

# %%
df_noyear_y
# Out:
#        index          id                                                url  \
# 0        194  7316725360  https://bham.craigslist.org/ctd/d/new-castle-2...
# 1        350  7315206704  https://bham.craigslist.org/ctd/d/new-castle-2...
# 2        578  7313325014  https://bham.craigslist.org/ctd/d/new-castle-2...
# 3        678  7312246404  https://bham.craigslist.org/ctd/d/new-castle-2...
# 4        710  7311854375  https://bham.craigslist.org/ctd/d/new-castle-2...
# ...      ...         ...                                                ...
# 1105  412079  7302025563  https://wenatchee.craigslist.org/ctd/d/wenatch...
# 1106  414161  7305586850  https://charlestonwv.craigslist.org/ctd/d/broa...
# 1107  414162  7305586184  https://charlestonwv.craigslist.org/ctd/d/broa...
# 1108  423519  7312866286  https://milwaukee.craigslist.org/ctd/d/milwauk...
# 1109  423528  7312863529  https://milwaukee.craigslist.org/ctd/d/milwauk...
#
#           region                           region_url  price  year  \
# 0     birmingham          https://bham.craigslist.org  33990   NaN
# 1109  2019 *Jeep* *Renegade* LATITUDE 4WD ONE OWNER ...    NaN    wi
#
#             lat        long              posting_date
# 0     33.669601  -86.817617  2021-05-04T10:11:04-0500
# 1     33.669601  -86.817617  2021-05-01T04:40:22-0500
# 2     33.669601  -86.817617  2021-04-27T10:10:59-0500
# 3     33.669601  -86.817617  2021-04-25T04:40:35-0500
# 4     33.669601  -86.817617  2021-04-24T10:01:21-0500
# ...         ...         ...                       ...
# 1105  47.434493 -120.320759  2021-04-05T07:10:39-0700
# 1106  38.767754  -77.707905  2021-04-12T10:06:31-0400
# 1107  38.767754  -77.707905  2021-04-12T10:05:21-0400
# 1108  43.176636  -88.023648  2021-04-26T11:42:40-0500
# 1109  43.176636  -88.023648  2021-04-26T11:38:41-0500
#
# [1057 rows x 27 columns]

# %%
df_noyear_y.isnull().sum()
# Out:
# id                 0
# url                0
# region             0
# region_url         0
# price              0
# year            1057
# manufacturer    1053
# model              0
# condition       1057
# cylinders          7
# fuel             193
# odometer           0
# title_status     242
# transmission       0
# VIN                0
# drive            219
# size            1057
# type             111
# paint_color       75
# image_url          0
# description        0
# county          1057
# state              0
# lat                0
# long               0
# posting_date       0
# dtype: int64

# %%
df_dupes = df[df.duplicated(subset=['paint_color','state','year','odometer','model','manufacturer','image_url','posting_date','cylinders'])]
df_dupes

# %%
#def impute_year(edf, year):
    #edf.year = edf.year.apply()
'''
for i, j in df_noyear_y.iterrows():
    print(i)
    #desc = df_noyear_y.iloc[i]['description']
    #print(desc)

    for yr in stringyears:
        if yr in desc:
            print(yr)
    for brand in cars:
        if brand in desc.upper():
            print(brand)
    for car in cars:
        if car.upper() in desc.upper():
            print(car)
    print('\n')
''' 

df_noyear_y.iloc[78]
#df_noyear_y.index
            
    
#df_noyear_y['year'] = df_noyear_y['year'].apply()
# Out:
# index                                                        9740
# id                                                     7303274902
# url             https://mohave.craigslist.org/ctd/d/lake-havas...
# region                                              mohave county
# region_url                          https://mohave.craigslist.org
# price                                                       24987
# year                                                          NaN
# manufacturer                                                  NaN
# model                                                         500
# condition                                                     NaN
# cylinders                                             8 cylinders
# fuel                                                          gas
# odometer                                                  68853.0
# title_status                                                  NaN
# transmission                                            automatic
# VIN                                             3C6RR6KT7JG252355
# drive                                                         rwd
# size                                                          NaN
# type                                                       pickup
# paint_color                                                 white
# image_url       https://images.craigslist.org/00q0q_cLozePIhPq...
# description     2018 *Ram* *1500* Tradesman 4x2 Crew Cab 5'7" ...
# county                                                        NaN
# state                                                          az
# lat                                                     34.544258
# long                                                  -114.352806
# posting_date                             2021-04-07T12:11:14-0700
# Name: 79, dtype: object

# %%
df_dupes2 = df[df.duplicated(subset=['paint_color','state','year','odometer','model','manufacturer','price'])]
df_dupes

# %%
def impute_manufacturer(car_model):
    df.model[df.model.str.upper().str.contains(car_model) & df.manufacturer.isnull()].unique()

# %%
df['description'].value_counts()

# %%
for row in df_manu.iterrows():

# %%
df = df[df['year'].notna()]
df = df[df['model'].notna()]
