# %%
import pandas as pd

# %%
df = pd.read_csv('data_EDA.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv('data_EDA.csv')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data_EDA.csv'

# %%
df.head()

# %%
df.shape

# %%
from sklearn.model_selection import train_test_split

X = df.drop(['price'], axis=1)
y = df['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from sklearn.model_selection import train_test_split
# ----> 3 X = df.drop(['price'], axis=1)
#       4 y = df['price']
#       6 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)
#
# NameError: name 'df' is not defined

# %%
useful_categoricals = ['GVWR', 'ABS', 'AirBagLocCurtain', 'AirBagLocSide', 'BodyClass', 'BrakeSystemType','Doors', 'DriveType', 
        'DynamicBrakeSupport', 'ESC', 'EngineConfiguration', 'EngineCylinders', 'FuelInjectionType','FuelTypePrimary',
        'KeylessIgnition', 'RearVisibilitySystem', 'ValveTrainDesign', 'Turbo', 'ValveTrainDesign']

less_useful_categoricals = ['AdaptiveCruiseControl', 'AdaptiveDrivingBeam', 'AirBagLocKnee', 'AutoReverseSystem','BlindSpotMon',
            'CAN_AACN', 'CIB', 'EngineCycles', 'ForwardCollisionWarning', 'FuelTypeSecondary',
            'LaneDepartureWarning', 'LaneKeepSystem', 'LowerBeamHeadlampLightSource',  'PedestrianAutomaticEmergencyBraking',
            'Pretensioner', 'SeatRows', 'Seats', 'SemiautomaticHeadlampBeamSwitching', 'TractionControl', 'TransmissionSpeeds',
            'TransmissionStyle', 'WheelSizeFront', 'WheelSizeRear', 'Windows']

veh_indicators = ['Make', 'Model', 'Series','Series2','Trim','Trim2',
    'VehicleDescriptor', 'VehicleType', 'VIN']

number_cols = ['BasePrice', 'DisplacementCC', 'EngineHP', 'Year', 'odometer']

target=['price']

# %%
dummies = useful_categoricals + less_useful_categoricals
df_cat = df[dummies]
df_no_cat = df[number_cols]

# %%
print(df_cat.columns.to_list() == dummies)
print(df_no_cat.columns.to_list() == number_cols)
# Out:
# True
# True

# %%
df_dummies = pd.get_dummies(df_cat.astype(str))
df_dummies.columns.to_list()
# Out:
# ['GVWR_Class 1: 6,000 lb or less (2,722 kg or less)',
#  'GVWR_Class 1A: 3,000 lb or less (1,360 kg or less)',
#  'GVWR_Class 1B: 3,001 - 4,000 lb (1,360 - 1,814 kg)',
#  'GVWR_Class 1C: 4,001 - 5,000 lb (1,814 - 2,268 kg)',
#  'GVWR_Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)',
#  'GVWR_Class 2: 6,001 - 10,000 lb (2,722 - 4,536 kg)',
#  'GVWR_Class 2E: 6,001 - 7,000 lb (2,722 - 3,175 kg)',
#  'GVWR_Class 2F: 7,001 - 8,000 lb (3,175 - 3,629 kg)',
#  'GVWR_Class 2G: 8,001 - 9,000 lb (3,629 - 4,082 kg)',
#  'GVWR_Class 2H: 9,001 - 10,000 lb (4,082 - 4,536 kg)',
#  'GVWR_Class 3: 10,001 - 14,000 lb (4,536 - 6,350 kg)',
#  'GVWR_Class 4: 14,001 - 16,000 lb (6,350 - 7,258 kg)',
#  'GVWR_Class 6: 19,501 - 26,000 lb (8,845 - 11,794 kg)',
#  'GVWR_Class 7: 26,001 - 33,000 lb (11,794 - 14,969 kg)',
#  'GVWR_Class 8: 33,001 lb and above (14,969 kg and above)',
#  'GVWR_nan',
#  'ABS_Optional',
#  'ABS_Standard',
#  'ABS_nan',
#  'AirBagLocCurtain_1st Row (Driver and Passenger)',
#  'AirBagLocCurtain_1st and 2nd Rows',
#  'AirBagLocCurtain_1st and 2nd and 3rd Rows',
#  'AirBagLocCurtain_All Rows',
#  'AirBagLocCurtain_Driver Seat Only',
#  'AirBagLocCurtain_nan',
#  'AirBagLocSide_1st Row (Driver and Passenger)',
#  'AirBagLocSide_1st and 2nd Rows',
#  'AirBagLocSide_1st and 2nd and 3rd Rows',
#  'AirBagLocSide_All Rows',
#  'AirBagLocSide_Driver Seat Only',
#  'AirBagLocSide_Passenger Seat Only',
#  'AirBagLocSide_nan',
#  'BodyClass_Cargo Van',
#  'BodyClass_Convertible/Cabriolet',
#  'BodyClass_Coupe',
#  'BodyClass_Crossover Utility Vehicle (CUV)',
#  'BodyClass_Fire Apparatus',
#  'BodyClass_Hatchback/Liftback/Notchback',
#  'BodyClass_Incomplete - Chassis Cab (Number of Cab Unknown)',
#  'BodyClass_Incomplete - Chassis Cab (Single Cab)',
#  'BodyClass_Limousine',
#  'BodyClass_Minivan',
#  'BodyClass_Pickup',
#  'BodyClass_Roadster',
#  'BodyClass_Sedan/Saloon',
#  'BodyClass_Sport Utility Truck (SUT)',
#  'BodyClass_Sport Utility Vehicle (SUV)/Multi-Purpose Vehicle (MPV)',
#  'BodyClass_Step Van / Walk-in Van',
#  'BodyClass_Truck',
#  'BodyClass_Truck-Tractor',
#  'BodyClass_Van',
#  'BodyClass_Wagon',
#  'BodyClass_nan',
#  'BrakeSystemType_Air',
#  'BrakeSystemType_Hydraulic',
#  'BrakeSystemType_nan',
#  'Doors_2.0',
#  'Doors_3.0',
#  'Doors_4.0',
#  'Doors_5.0',
#  'Doors_6.0',
#  'Doors_nan',
#  'DriveType_2WD/4WD',
#  'DriveType_4WD/4-Wheel Drive/4x4',
#  'DriveType_4x2',
#  'DriveType_6x4',
#  'DriveType_AWD/All-Wheel Drive',
#  'DriveType_FWD/Front-Wheel Drive',
#  'DriveType_RWD/Rear-Wheel Drive',
#  'DriveType_nan',
#  'DynamicBrakeSupport_Not Available',
#  'DynamicBrakeSupport_Optional',
#  'DynamicBrakeSupport_Standard',
#  'DynamicBrakeSupport_nan',
#  'ESC_Standard',
#  'ESC_nan',
#  'EngineConfiguration_Horizontally opposed (boxer)',
#  'EngineConfiguration_In-Line',
#  'EngineConfiguration_V-Shaped',
#  'EngineConfiguration_W Shaped',
#  'EngineConfiguration_nan',
#  'EngineCylinders_10.0',
#  'EngineCylinders_12.0',
#  'EngineCylinders_2.0',
#  'EngineCylinders_3.0',
#  'EngineCylinders_4.0',
#  'EngineCylinders_5.0',
#  'EngineCylinders_6.0',
#  'EngineCylinders_8.0',
#  'EngineCylinders_nan',
#  'FuelInjectionType_Common Rail Direct Injection Diesel (CRDI)',
#  'FuelInjectionType_Multipoint Fuel Injection (MPFI)',
#  'FuelInjectionType_Sequential Fuel Injection (SFI)',
#  'FuelInjectionType_Stoichiometric Gasoline Direct Injection (SGDI)',
#  'FuelInjectionType_Throttle Body Fuel Injection (TBI)',
#  'FuelInjectionType_Unit Injector Direct Injection Diesel (UDI)',
#  'FuelInjectionType_nan',
#  'FuelTypePrimary_Compressed Natural Gas (CNG)',
#  'FuelTypePrimary_Diesel',
#  'FuelTypePrimary_Electric',
#  'FuelTypePrimary_Ethanol (E85)',
#  'FuelTypePrimary_Flexible Fuel Vehicle (FFV)',
#  'FuelTypePrimary_Fuel Cell',
#  'FuelTypePrimary_Gasoline',
#  'FuelTypePrimary_nan',
#  'KeylessIgnition_Not Available',
#  'KeylessIgnition_Optional',
#  'KeylessIgnition_Standard',
#  'KeylessIgnition_nan',
#  'RearVisibilitySystem_Not Available',
#  'RearVisibilitySystem_Optional',
#  'RearVisibilitySystem_Standard',
#  'RearVisibilitySystem_nan',
#  'ValveTrainDesign_Dual Overhead Cam (DOHC)',
#  'ValveTrainDesign_Overhead Valve (OHV)',
#  'ValveTrainDesign_Single Overhead Cam (SOHC)',
#  'ValveTrainDesign_nan',
#  'Turbo_No',
#  'Turbo_Yes',
#  'Turbo_nan',
#  'ValveTrainDesign_Dual Overhead Cam (DOHC)',
#  'ValveTrainDesign_Overhead Valve (OHV)',
#  'ValveTrainDesign_Single Overhead Cam (SOHC)',
#  'ValveTrainDesign_nan',
#  'AdaptiveCruiseControl_Not Available',
#  'AdaptiveCruiseControl_Optional',
#  'AdaptiveCruiseControl_Standard',
#  'AdaptiveCruiseControl_nan',
#  'AdaptiveDrivingBeam_Not Available',
#  'AdaptiveDrivingBeam_Optional',
#  'AdaptiveDrivingBeam_Standard',
#  'AdaptiveDrivingBeam_nan',
#  'AirBagLocKnee_1st Row (Driver and Passenger)',
#  'AirBagLocKnee_Driver Seat Only',
#  'AirBagLocKnee_Passenger Seat Only',
#  'AirBagLocKnee_nan',
#  'AutoReverseSystem_Not Available',
#  'AutoReverseSystem_Optional',
#  'AutoReverseSystem_Standard',
#  'AutoReverseSystem_nan',
#  'BlindSpotMon_Not Available',
#  'BlindSpotMon_Optional',
#  'BlindSpotMon_Standard',
#  'BlindSpotMon_nan',
#  'CAN_AACN_Not Available',
#  'CAN_AACN_Optional',
#  'CAN_AACN_Standard',
#  'CAN_AACN_nan',
#  'CIB_Not Available',
#  'CIB_Optional',
#  'CIB_Standard',
#  'CIB_nan',
#  'EngineCycles_2.0',
#  'EngineCycles_4.0',
#  'EngineCycles_6.0',
#  'EngineCycles_8.0',
#  'EngineCycles_nan',
#  'ForwardCollisionWarning_Not Available',
#  'ForwardCollisionWarning_Optional',
#  'ForwardCollisionWarning_Standard',
#  'ForwardCollisionWarning_nan',
#  'FuelTypeSecondary_Compressed Natural Gas (CNG)',
#  'FuelTypeSecondary_Electric',
#  'FuelTypeSecondary_Ethanol (E85)',
#  'FuelTypeSecondary_Flexible Fuel Vehicle (FFV)',
#  'FuelTypeSecondary_Gasoline',
#  'FuelTypeSecondary_Liquefied Petroleum Gas (propane or LPG)',
#  'FuelTypeSecondary_nan',
#  'LaneDepartureWarning_Not Available',
#  'LaneDepartureWarning_Optional',
#  'LaneDepartureWarning_Standard',
#  'LaneDepartureWarning_nan',
#  'LaneKeepSystem_Not Available',
#  'LaneKeepSystem_Optional',
#  'LaneKeepSystem_Standard',
#  'LaneKeepSystem_nan',
#  'LowerBeamHeadlampLightSource_HID',
#  'LowerBeamHeadlampLightSource_Halogen',
#  'LowerBeamHeadlampLightSource_Halogen, HID',
#  'LowerBeamHeadlampLightSource_Halogen, LED',
#  'LowerBeamHeadlampLightSource_LED',
#  'LowerBeamHeadlampLightSource_nan',
#  'PedestrianAutomaticEmergencyBraking_Not Available',
#  'PedestrianAutomaticEmergencyBraking_Optional',
#  'PedestrianAutomaticEmergencyBraking_Standard',
#  'PedestrianAutomaticEmergencyBraking_nan',
#  'Pretensioner_Yes',
#  'Pretensioner_nan',
#  'SeatRows_1.0',
#  'SeatRows_2.0',
#  'SeatRows_3.0',
#  'SeatRows_4.0',
#  'SeatRows_nan',
#  'Seats_12.0',
#  'Seats_2.0',
#  'Seats_3.0',
#  'Seats_4.0',
#  'Seats_5.0',
#  'Seats_6.0',
#  'Seats_7.0',
#  'Seats_8.0',
#  'Seats_nan',
#  'SemiautomaticHeadlampBeamSwitching_Not Available',
#  'SemiautomaticHeadlampBeamSwitching_Optional',
#  'SemiautomaticHeadlampBeamSwitching_Standard',
#  'SemiautomaticHeadlampBeamSwitching_nan',
#  'TractionControl_Optional',
#  'TractionControl_Standard',
#  'TractionControl_nan',
#  'TransmissionSpeeds_1.0',
#  'TransmissionSpeeds_10.0',
#  'TransmissionSpeeds_2.0',
#  'TransmissionSpeeds_3.0',
#  'TransmissionSpeeds_4.0',
#  'TransmissionSpeeds_5.0',
#  'TransmissionSpeeds_6.0',
#  'TransmissionSpeeds_7.0',
#  'TransmissionSpeeds_8.0',
#  'TransmissionSpeeds_9.0',
#  'TransmissionSpeeds_nan',
#  'TransmissionStyle_Automated Manual Transmission (AMT)',
#  'TransmissionStyle_Automatic',
#  'TransmissionStyle_Continuously Variable Transmission (CVT)',
#  'TransmissionStyle_Dual-Clutch Transmission (DCT)',
#  'TransmissionStyle_Electronic Continuously Variable (e-CVT)',
#  'TransmissionStyle_Manual/Standard',
#  'TransmissionStyle_nan',
#  'WheelSizeFront_14.0',
#  'WheelSizeFront_15.0',
#  'WheelSizeFront_16.0',
#  'WheelSizeFront_17.0',
#  'WheelSizeFront_18.0',
#  'WheelSizeFront_19.0',
#  'WheelSizeFront_20.0',
#  'WheelSizeFront_21.0',
#  'WheelSizeFront_22.0',
#  'WheelSizeFront_nan',
#  'WheelSizeRear_14.0',
#  'WheelSizeRear_15.0',
#  'WheelSizeRear_16.0',
#  'WheelSizeRear_17.0',
#  'WheelSizeRear_18.0',
#  'WheelSizeRear_19.0',
#  'WheelSizeRear_20.0',
#  'WheelSizeRear_21.0',
#  'WheelSizeRear_22.0',
#  'WheelSizeRear_nan',
#  'Windows_4.0',
#  'Windows_6.0',
#  'Windows_nan']

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler() 
scaled_df = scaler.fit_transform(df_no_cat) 
scaled_df = pd.DataFrame(scaled_df, columns=number_cols) 

scaled_df.head()
# Out:
#    BasePrice  DisplacementCC  EngineHP      Year  odometer
# 0        NaN        1.325693       NaN  0.232840 -0.635785
# 1        NaN        1.325693       NaN -0.518091 -0.400676
# 2        NaN        1.325693       NaN  1.359235 -1.320704
# 3  -0.156275        0.840787  0.737277  0.796037 -0.932614
# 4        NaN        1.810598       NaN -0.142626 -0.445433

# %%
new_df = pd.concat([scaled_df, df_dummies, df['price']], axis=1)
new_df.shape
# Out:
# (90493, 256)

# %%
from sklearn.model_selection import train_test_split

X = new_df.drop(['price'], axis=1)
y = new_df['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)
