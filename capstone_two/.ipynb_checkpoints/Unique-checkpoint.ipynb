# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import requests,json;

# %%
uniq = pd.read_csv('unique_y.csv')
uniq.head()
# Out:
# C:\Users\mitch\AppData\Local\Temp\ipykernel_22616\663282851.py:1: DtypeWarning: Columns (42) have mixed types. Specify dtype option on import or set low_memory=False.
#   uniq = pd.read_csv('unique_y.csv')
#    Unnamed: 0       ABS ActiveSafetySysNote AdaptiveCruiseControl  \
# 0           0       NaN                 NaN                   NaN
# 1           1       NaN                 NaN                   NaN
# 2           2  Standard                 NaN              Optional
# 3           3  Standard                 NaN                   NaN
# 4           4       NaN                 NaN                   NaN
#
#   AdaptiveDrivingBeam  AdaptiveHeadlights AdditionalErrorText  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# ...

# %%
uniq = uniq.drop('Unnamed: 0', axis=1)
uniq.head()
# Out:
#         ABS ActiveSafetySysNote AdaptiveCruiseControl AdaptiveDrivingBeam  \
# 0       NaN                 NaN                   NaN                 NaN
# 1       NaN                 NaN                   NaN                 NaN
# 2  Standard                 NaN              Optional                 NaN
# 3  Standard                 NaN                   NaN                 NaN
# 4       NaN                 NaN                   NaN                 NaN
#
#    AdaptiveHeadlights AdditionalErrorText AirBagLocCurtain  \
# 0                 NaN                 NaN         All Rows
# 1                 NaN                 NaN              NaN
# 2                 NaN                 NaN         All Rows
# 3                 NaN                 NaN         All Rows
# 4                 NaN                 NaN              NaN
#
#                    AirBagLocFront                   AirBagLocKnee  \
# 0  1st Row (Driver and Passenger)                             NaN
# ...

# %%
uniq.shape
# Out:
# (14423, 150)

# %%
uniq2 = uniq.drop_duplicates(subset=['Make', 'Model', 'ModelYear'])
indices = uniq2.index.tolist()
uniq2.shape
# Out:
# (6609, 150)

# %%
uniq2.loc[:, ['Make', 'Model', 'ModelYear', 'Series','Series2','Trim','Trim2']].head(25)
# Out:
#          Make      Model  ModelYear  \
# 0         GMC     Sierra     2014.0
# 1   CHEVROLET  Silverado     2010.0
# 2   CHEVROLET  Silverado     2020.0
# 3      TOYOTA     Tundra     2017.0
# 4         GMC     Sierra     2012.0
# 5   CHEVROLET  Silverado     2016.0
# 6   CHEVROLET   Colorado     2016.0
# 7   CHEVROLET   Corvette     2011.0
# 8        JEEP   Wrangler     2017.0
# 9   CHEVROLET  Silverado     2017.0
# 11     TOYOTA     Tacoma     2014.0
# 12  CHEVROLET     Camaro     2016.0
# 13     TOYOTA     Tundra     2014.0
# 14       FORD     Ranger     2019.0
# 15     NISSAN   Frontier     2018.0
# 16       FORD      F-150     2018.0
# 17     TOYOTA     Tacoma     2016.0
# 18       JEEP   Wrangler     2020.0
# 19       FORD      F-150     2020.0
# 20        RAM       1500     2017.0
# 21      MAZDA       MX-5     2020.0
# 22       FORD     Ranger     2020.0
# 23   CADILLAC        XT4     2019.0
# 24       JEEP   Renegade     2016.0
# 25       FORD      F-150     2016.0
#
# ...

# %%
uniq2.to_csv('uniq2.csv', index=False)
