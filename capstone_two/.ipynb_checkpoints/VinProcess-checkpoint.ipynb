# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import requests,json;

# %%
vinny = pd.read_csv('data/craigslist_withVins.csv')
vinny.head()
# Out:
#            id                                                url  region  \
# 0  7316814884  https://auburn.craigslist.org/ctd/d/auburn-uni...  auburn
# 1  7316814758  https://auburn.craigslist.org/ctd/d/auburn-uni...  auburn
# 2  7316814989  https://auburn.craigslist.org/ctd/d/auburn-uni...  auburn
# 3  7316743432  https://auburn.craigslist.org/ctd/d/auburn-uni...  auburn
# 4  7316343444  https://auburn.craigslist.org/ctd/d/auburn-uni...  auburn
#
#                       region_url  price    year manufacturer  \
# 0  https://auburn.craigslist.org  33590  2014.0          gmc
# 1  https://auburn.craigslist.org  22590  2010.0    chevrolet
# 2  https://auburn.craigslist.org  39590  2020.0    chevrolet
# 3  https://auburn.craigslist.org  30990  2017.0       toyota
# 4  https://auburn.craigslist.org  27990  2012.0          gmc
#
#                          model condition    cylinders  ... size    type  \
# 0     sierra 1500 crew cab slt      good  8 cylinders  ...  NaN  pickup
# ...

# %%
vinny.isnull().sum()
# Out:
# id                   0
# url                  0
# region               0
# region_url           0
# price                0
# year               583
# manufacturer      2746
# model              496
# condition        46528
# cylinders        40191
# fuel              1354
# odometer           550
# title_status      2993
# transmission       881
# VIN                  0
# drive            22822
# size             75339
# type             13598
# paint_color      23481
# image_url            0
# description          1
# county          101928
# state                0
# lat                809
# long               809
# posting_date         0
# dtype: int64

# %%
vinny[vinny.manufacturer.isnull()]
# Out:
#                 id                                                url  \
# 59      7309271279  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 89      7305150004  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 107     7302642422  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 122     7316725360  https://bham.craigslist.org/ctd/d/new-castle-2...
# 143     7316206718  https://bham.craigslist.org/ctd/d/new-castle-2...
# ...            ...                                                ...
# 101585  7307911359  https://milwaukee.craigslist.org/ctd/d/milwauk...
# 101663  7315478843  https://sheboygan.craigslist.org/cto/d/plymout...
# 101777  7313868777  https://wausau.craigslist.org/cto/d/marshfield...
# 101867  7305281414  https://wausau.craigslist.org/cto/d/port-edwar...
# 101923  7305969547  https://wyoming.craigslist.org/ctd/d/casper-20...
#
#             region                        region_url  price    year  \
# ...

# %%
all_vins = vinny.VIN.tolist()
len(all_vins)
# Out:
# 101928

# %%
with
# Out:
# ['3GTP1VEC4EG551563',
#  '1GCSCSE06AZ123805',
#  '3GCPWCED5LG130317',
#  '5TFRM5F17HX120972',
#  '1GT220CG8CZ231238',
#  '1GCVKREH6GZ228691',
#  '1GCHTCE37G1186784',
#  '1G1YR3DW3B5102190',
#  '1C4BJWDG5HL705371',
#  '1GCNCNEH7HZ118773',
#  '1GCGTDE32G1341288',
#  '5TFTX4CN3EX042751',
#  '1G1FF1R79G0140582',
#  '5TFEY5F15EX169621',
#  '1FTER4EH3KLA31326',
#  '1N6AD0EV5JN745213',
#  '1FTEX1CBXJKD41626',
#  '3TMAZ5CN7GM019182',
#  '1C4GJXAN4LW180633',
#  '1FTEW1CP4LFB84170',
#  '3C6JR6DT3HG557601',
#  'JM1NDAC74L0413665',
#  '1FTER1EH1LLA36301',
#  '1GYFZER40KF121673',
#  'ZACCJBAW9GPC62449',
#  '1FTMF1CP3GKD62143',
#  '1GTN1TEH9FZ243281',
#  '1C6RR6FG0JS259587',
#  '1GTR1WE07DZ143724',
#  '3C6JR6DT3KG560649',
#  '1FATP8FF5J5115190',
#  '1GCHSCEA7H1203280',
#  '2GCVKNEC8K1187169',
#  '5TFUY5F19DX303623',
#  '1GCVKREC7EZ196951',
#  '1GCNCNEH4GZ259783',
#  '5TFTX4CN6CX015282',
#  '3GCPCREH5EG437908',
#  '1C4HJWEG5HL696454',
#  '2HGFC3A51LH751302',
#  '19XFC2F59JE206832',
# ...

# %%
print(all_vins[:49])
# Out:
# ['3GTP1VEC4EG551563', '1GCSCSE06AZ123805', '3GCPWCED5LG130317', '5TFRM5F17HX120972', '1GT220CG8CZ231238', '1GCVKREH6GZ228691', '1GCHTCE37G1186784', '1G1YR3DW3B5102190', '1C4BJWDG5HL705371', '1GCNCNEH7HZ118773', '1GCGTDE32G1341288', '5TFTX4CN3EX042751', '1G1FF1R79G0140582', '5TFEY5F15EX169621', '1FTER4EH3KLA31326', '1N6AD0EV5JN745213', '1FTEX1CBXJKD41626', '3TMAZ5CN7GM019182', '1C4GJXAN4LW180633', '1FTEW1CP4LFB84170', '3C6JR6DT3HG557601', 'JM1NDAC74L0413665', '1FTER1EH1LLA36301', '1GYFZER40KF121673', 'ZACCJBAW9GPC62449', '1FTMF1CP3GKD62143', '1GTN1TEH9FZ243281', '1C6RR6FG0JS259587', '1GTR1WE07DZ143724', '3C6JR6DT3KG560649', '1FATP8FF5J5115190', '1GCHSCEA7H1203280', '2GCVKNEC8K1187169', '5TFUY5F19DX303623', '1GCVKREC7EZ196951', '1GCNCNEH4GZ259783', '5TFTX4CN6CX015282', '3GCPCREH5EG437908', '1C4HJWEG5HL696454', '2HGFC3A51LH751302', '19XFC2F59JE206832', '1FMJU1JT1HEA52352', '2HGFC2F74JH589649', '1FTEX1CMXDFB16329', '1C4GJXAG9LW193038', '3TMLU4EN4CM085701', '1FTEW1CP2KKC65268', 'JTJBJRBZ8
# ...

# %%
string = '''3GTP1VEC4EG551563; 1GCSCSE06AZ123805; 3GCPWCED5LG130317; 5TFRM5F17HX120972; 1GT220CG8CZ231238; 1GCVKREH6GZ228691; 1GCHTCE37G1186784; 1G1YR3DW3B5102190; 1C4BJWDG5HL705371; 1GCNCNEH7HZ118773; 1GCGTDE32G1341288; 5TFTX4CN3EX042751; 1G1FF1R79G0140582; 5TFEY5F15EX169621; 1FTER4EH3KLA31326; 1N6AD0EV5JN745213; 1FTEX1CBXJKD41626; 3TMAZ5CN7GM019182; 1C4GJXAN4LW180633; 1FTEW1CP4LFB84170; 3C6JR6DT3HG557601; JM1NDAC74L0413665; 1FTER1EH1LLA36301; 1GYFZER40KF121673; ZACCJBAW9GPC62449; 1FTMF1CP3GKD62143; 1GTN1TEH9FZ243281; 1C6RR6FG0JS259587; 1GTR1WE07DZ143724; 3C6JR6DT3KG560649; 1FATP8FF5J5115190; 1GCHSCEA7H1203280; 2GCVKNEC8K1187169; 5TFUY5F19DX303623; 1GCVKREC7EZ196951; 1GCNCNEH4GZ259783; 5TFTX4CN6CX015282; 3GCPCREH5EG437908; 1C4HJWEG5HL696454; 2HGFC3A51LH751302; 19XFC2F59JE206832; 1FMJU1JT1HEA52352; 2HGFC2F74JH589649; 1FTEX1CMXDFB16329; 1C4GJXAG9LW193038; 3TMLU4EN4CM085701; 1FTEW1CP2KKC65268; JTJBJRBZ8F2020836; SADFJ2FX1J1Z13468'''
string.replace(' ','')
# Out:
# '3GTP1VEC4EG551563;1GCSCSE06AZ123805;3GCPWCED5LG130317;5TFRM5F17HX120972;1GT220CG8CZ231238;1GCVKREH6GZ228691;1GCHTCE37G1186784;1G1YR3DW3B5102190;1C4BJWDG5HL705371;1GCNCNEH7HZ118773;1GCGTDE32G1341288;5TFTX4CN3EX042751;1G1FF1R79G0140582;5TFEY5F15EX169621;1FTER4EH3KLA31326;1N6AD0EV5JN745213;1FTEX1CBXJKD41626;3TMAZ5CN7GM019182;1C4GJXAN4LW180633;1FTEW1CP4LFB84170;3C6JR6DT3HG557601;JM1NDAC74L0413665;1FTER1EH1LLA36301;1GYFZER40KF121673;ZACCJBAW9GPC62449;1FTMF1CP3GKD62143;1GTN1TEH9FZ243281;1C6RR6FG0JS259587;1GTR1WE07DZ143724;3C6JR6DT3KG560649;1FATP8FF5J5115190;1GCHSCEA7H1203280;2GCVKNEC8K1187169;5TFUY5F19DX303623;1GCVKREC7EZ196951;1GCNCNEH4GZ259783;5TFTX4CN6CX015282;3GCPCREH5EG437908;1C4HJWEG5HL696454;2HGFC3A51LH751302;19XFC2F59JE206832;1FMJU1JT1HEA52352;2HGFC2F74JH589649;1FTEX1CMXDFB16329;1C4GJXAG9LW193038;3TMLU4EN4CM085701;1FTEW1CP2KKC65268;JTJBJRBZ8F2020836;SADFJ2FX1J1Z13468'

# %%
def test_vin(vin):
    url_base = 'https://vpic.nhtsa.dot.gov/api/vehicles/DecodeVINValuesBatch/'
    form = '?format=json'
    url = url_base+vin+form
    return requests.get(url).json()
x = test_vin('3GTP1VEC4EG551563')

# %%
x['Results']
# Out:
# [{'ABS': '',
#   'ActiveSafetySysNote': '',
#   'AdaptiveCruiseControl': '',
#   'AdaptiveDrivingBeam': '',
#   'AdaptiveHeadlights': '',
#   'AdditionalErrorText': '',
#   'AirBagLocCurtain': 'All Rows',
#   'AirBagLocFront': '1st Row (Driver and Passenger)',
#   'AirBagLocKnee': '',
#   'AirBagLocSeatCushion': '',
#   'AirBagLocSide': '1st Row (Driver and Passenger)',
#   'AutoReverseSystem': '',
#   'AutomaticPedestrianAlertingSound': '',
#   'AxleConfiguration': '',
#   'Axles': '',
#   'BasePrice': '',
#   'BatteryA': '',
#   'BatteryA_to': '',
#   'BatteryCells': '',
#   'BatteryInfo': '',
#   'BatteryKWh': '',
#   'BatteryKWh_to': '',
#   'BatteryModules': '',
#   'BatteryPacks': '',
#   'BatteryType': '',
#   'BatteryV': '',
#   'BatteryV_to': '',
#   'BedLengthIN': '',
#   'BedType': '',
#   'BlindSpotIntervention': '',
#   'BlindSpotMon': '',
#   'BodyCabType': 'Crew/Super Crew/Crew Max',
#   'BodyClass': 'Pickup',
#   'BrakeSystemDesc': '',
# ...

# %%
#return df from batch of 50 or less VIN #'s in VIN;VIN;VIN format
def batch_VIN(vinlis):
    url = 'https://vpic.nhtsa.dot.gov/api/vehicles/DecodeVINValuesBatch/'
    post_fields = {'format': 'json', 'data':vinlis}
    r = requests.post(url, data=post_fields)
    return pd.DataFrame.from_dict(json.loads(r.text)['Results'])

# %%
def create_vin_strings(vin_lis):
    if len(vin_lis) < 51:
        stri = ';'.join(vin_lis)
        return stri
    else:
        return 'vin list too long'

# %%
batch2 = all_vins[50: 100]
create_vin_strings(batch2)
# Out:
# 'JTJAARBZ1L2159357;YV4612UMXG2000759;7JRA22TL6KG004114;7JR102FK7LG060315;7JR102FK4KG010003;WA1ANAFY7J2102310;5N1AL0MM5FC519184;1LN6L9TP6H5634048;ZASFAKBN3J7B64774;JTNKARJEXGJ517925;2HNYD2H30DH510846;WAUC8AFC6JN041814;5NPE34AF8FH021634;3C6RR7KT7HG794054;2GTV2LECXK1123316;1GTR1WE01DZ407455;1FTBF2B65KEC91136;1C4BJWDG2JL806552;1C4HJXEN4KW505794;1C4BJWFG3HL547853;1C4HJXEGXJW175675;1GKKNLLS2JZ178034;3LN6L2G99DR819673;1GKKNMLS2HZ305977;3LN6L5A97HR666209;JTJYARBZ9F2013419;JTJYARBZ5G2041512;KL4MMDSL8LB104338;SADFP2FX0J1Z05358;LYV402TK9JB177497;7JRA22TM2KG013336;7JRA22TM4KG006873;7JRA22TM6KG005594;5N1DL0MN9LC508268;ZASFAKNN6J7B70368;1LN6L9TK4H5636420;WA1ANAFY2J2198475;5NPE34AF7JH658815;WAUG8AFC8JN040987;JTNKARJE4GJ508198;5J8YD4H39LL041518;1C4GJXAGXKW566358;1C4BJWDG5CL258372;4T1BF1FK4HU421581;1C6RR6VT3HS551162;1C4BJWFG7HL558919;1C4BJWDG7HL689576;1C4BJWDG8HL671975;1C4BJWDG6HL650381;WBAUP9C53CVL91190'

# %%
# 101928 is total number of vins
def create_master_list(lis):
    master = []
    counter = 0
    x = np.arange(0, len(lis), 50)
    for n in x:
        master.append(create_vin_strings(lis[counter: counter+50]))
        counter+= 50
    return master
masterlis = create_master_list(all_vins)

# %%
def giant_df(big_lis):
    dflis = []
    for big in big_lis:
        dflis.append(batch_VIN(big))
    return pd.concat(dflis)

# %%
gdf = giant_df(masterlis)

# %%
gdf.head()
# Out:
#         ABS ActiveSafetySysNote AdaptiveCruiseControl AdaptiveDrivingBeam  \
# 0
# 1
# 2  Standard                                  Optional
# 3  Standard
# 4
#
#   AdaptiveHeadlights AdditionalErrorText AirBagLocCurtain  \
# 0                                                All Rows
# 1
# 2                                                All Rows
# 3                                                All Rows
# 4
#
#                    AirBagLocFront                   AirBagLocKnee  \
# 0  1st Row (Driver and Passenger)
# 1  1st Row (Driver and Passenger)
# 2  1st Row (Driver and Passenger)
# 3  1st Row (Driver and Passenger)  1st Row (Driver and Passenger)
# 4  1st Row (Driver and Passenger)
#
#   AirBagLocSeatCushion  ...          ValveTrainDesign VehicleDescriptor  \
# 0                       ...                                 3GTP1VEC*EG
# 1                       ...      Overhead Valve (OHV)       1GCSCSE0*AZ
# 2                       ...                                 3GCPWCED*LG
# ...

# %%
gdf.to_csv('gdf.csv')

# %%
cols = gdf.columns.tolist()
cols
# Out:
# ['ABS',
#  'ActiveSafetySysNote',
#  'AdaptiveCruiseControl',
#  'AdaptiveDrivingBeam',
#  'AdaptiveHeadlights',
#  'AdditionalErrorText',
#  'AirBagLocCurtain',
#  'AirBagLocFront',
#  'AirBagLocKnee',
#  'AirBagLocSeatCushion',
#  'AirBagLocSide',
#  'AutoReverseSystem',
#  'AutomaticPedestrianAlertingSound',
#  'AxleConfiguration',
#  'Axles',
#  'BasePrice',
#  'BatteryA',
#  'BatteryA_to',
#  'BatteryCells',
#  'BatteryInfo',
#  'BatteryKWh',
#  'BatteryKWh_to',
#  'BatteryModules',
#  'BatteryPacks',
#  'BatteryType',
#  'BatteryV',
#  'BatteryV_to',
#  'BedLengthIN',
#  'BedType',
#  'BlindSpotIntervention',
#  'BlindSpotMon',
#  'BodyCabType',
#  'BodyClass',
#  'BrakeSystemDesc',
#  'BrakeSystemType',
#  'BusFloorConfigType',
#  'BusLength',
#  'BusType',
#  'CAN_AACN',
#  'CIB',
#  'CashForClunkers',
#  'ChargerLevel',
#  'ChargerPowerKW',
#  'CoolingType',
#  'CurbWeightLB',
#  'CustomMotorcycleType',
#  'DaytimeRunningLight',
#  'DestinationMarket',
#  'DisplacementCC',
# ...

# %%
gdf.ModelYear[(gdf.Make == 'CHEVROLET') & (gdf.Model == 'Impala')].value_counts()
# Out:
# ModelYear
# 2008    64
# 2012    55
# 2009    47
# 2010    47
# 2013    44
# 2011    44
# 2014    38
# 2006    32
# 2007    29
# 2017    28
# 2015    18
# 2019    17
# 2016    17
# 2004    17
# 2003    14
# 2018    12
# 2005     9
# 2020     7
# 2000     3
# 2002     3
# 2001     3
# Name: count, dtype: int64

# %%
gdf[['Make', 'Model', 'Trim', 'Trim2', 'ModelYear']]
# Out:
#    Count                                            Message SearchCriteria  \
# 0     49  Results returned successfully. NOTE: Any missi...
# 1     49  Results returned successfully. NOTE: Any missi...
# 2     49  Results returned successfully. NOTE: Any missi...
# 3     49  Results returned successfully. NOTE: Any missi...
# 4     49  Results returned successfully. NOTE: Any missi...
#
#                                              Results
# 0  {'ABS': '', 'ActiveSafetySysNote': '', 'Adapti...
# 1  {'ABS': '', 'ActiveSafetySysNote': '', 'Adapti...
# 2  {'ABS': 'Standard', 'ActiveSafetySysNote': '',...
# 3  {'ABS': 'Standard', 'ActiveSafetySysNote': '',...
# 4  {'ABS': '', 'ActiveSafetySysNote': '', 'Adapti...

# %%
dic = {}
for col in ['Make', 'Model', 'Trim', 'Trim2', 'ModelYear']:
    dic[col] = gdf[col].unique().tolist()
dic
# Out:
# {'Make': ['GMC',
#   'CHEVROLET',
#   'TOYOTA',
#   'JEEP',
#   'FORD',
#   'NISSAN',
#   'RAM',
#   'MAZDA',
#   'CADILLAC',
#   'HONDA',
#   'LEXUS',
#   'JAGUAR',
#   'BUICK',
#   'VOLVO',
#   'AUDI',
#   'INFINITI',
#   'LINCOLN',
#   'ALFA ROMEO',
#   'ACURA',
#   'HYUNDAI',
#   'BMW',
#   'CHRYSLER',
#   'MITSUBISHI',
#   'SMART',
#   'KIA',
#   'MASERATI',
#   'PORSCHE',
#   'SUZUKI',
#   'DODGE',
#   'MERCEDES-BENZ',
#   'SUBARU',
#   '',
#   'MINI',
#   'PONTIAC',
#   'VOLKSWAGEN',
#   'FIAT',
#   'LAND ROVER',
#   'GENESIS',
#   'HUMMER',
#   'ISUZU',
#   'HINO',
#   'INTERNATIONAL',
#   'MITSUBISHI FUSO',
#   'FREIGHTLINER',
#   'BLUE BIRD',
#   'WORKHORSE',
#   'TESLA',
#   'STERLING TRUCK',
#   'BENTLEY',
#   'YAMAHA',
#   'MERCURY',
#   'OLDSMOBILE',
#   'SAAB',
#   'SATURN',
#   'WESTERN STAR',
#   'KENWORTH',
#   'PETERBILT',
#   'LAMBORGHINI',
#   'FISKER',
#   'GREENGO TEK',
#   'VOLVO TRUCK',
#   'THOMAS BUILT',
#   'AM GENERAL',
#   'LOTUS',
#   'GEM',
# ...

# %%
no_make_df = gdf[gdf.Make == '']

# %%
no_make_df.to_csv('nomake.csv')

# %%
VIN17 = []

for each in no_make_df.VIN.unique().tolist():
    if len(each) == 17:
        VIN17.append(each)
VIN17
# Out:
# ['11111111111111111',
#  '1ZE1LMW24JAN52864',
#  '8D14X708X40881012',
#  'VBWGP61J014067279',
#  '0000000RN47028886',
#  '00001S87L9L616133',
#  'WAIDGAFP3DA046942',
#  '00000HDJ810018347',
#  'JTZMA67L8EQ109145',
#  'IC4BJWDG5JL861304',
#  'IJ4FJ28E4LL292638',
#  '7KXBT2119MP020230',
#  'V1200000000006407',
#  'V1200000001932735',
#  'JTIBU5JR5J5597489',
#  'IHGCR2F73DA147868',
#  '00000000000007904',
#  '00000000000005769',
#  '00000000000007846',
#  '00000000000007907',
#  '00000000000007905',
#  '00000000000007906',
#  '00000000000007910',
#  '00000000000005789',
#  '99999999999999999',
#  '1B9US121XH1245912',
#  'G9CGBSFGEV5002996',
#  'NMOGE9G24K1400343',
#  '1C6SRRU9XMN704930',
#  'STDZK23C49S264111',
#  'WPOAA2991SS322698',
#  'WDBHF5KB0EA895011',
#  '1FNEU15H0SLA49968',
#  '00000000000000000',
#  '91121109540000000',
#  'MWMRE35575TG96184',
#  '12000800000000000',
#  'WPOCB2A89DS132188',
#  'IGKFK66817J359256',
#  '1N4AZOCP4EC330643',
#  'WPOCA2996XS656550',
# ...

# %%
gdf[gdf.VIN.str.startswith('0')]
# Out:
#    ABS ActiveSafetySysNote AdaptiveCruiseControl AdaptiveDrivingBeam  \
# 26
# 27
# 22
# 24
# 30
# 31
# 49
# 0
# 2
# 4
# 5
# 25
# 17
# 34
# 30
# 36
# 12
# 22
# 23
# 24
# 9
# 20
# 18
# 12
# 14
# 15
# 16
# 26
# 35
# 34
# 31
# 30
# 9
# 18
# 21
# 39
# 38
# 39
# 1
# 12
# 4
# 35
#
#    AdaptiveHeadlights                                AdditionalErrorText  \
# 26                                            Invalid character(s): 9:N;
# 27                                            Invalid character(s): 9:L;
# 22
# 24                                           Invalid character(s): 10:0;
# 30                                           Invalid character(s): 10:0;
# 31                                           Invalid character(s): 10:0;
# 49                                           Invalid character(s): 10:0;
# 0                                            Invalid character(s): 10:0;
# 2                                            Invalid character(s): 10:0;
# ...
