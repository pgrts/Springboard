# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import requests,json;

# %%
gdf = pd.read_csv('gdf.csv')
gdf.head()
# Out:
# C:\Users\mitch\AppData\Local\Temp\ipykernel_24256\3812049270.py:1: DtypeWarning: Columns (14,30,42,80,102,104,106,115) have mixed types. Specify dtype option on import or set low_memory=False.
#   gdf = pd.read_csv('gdf.csv')
#    Unnamed: 0       ABS ActiveSafetySysNote AdaptiveCruiseControl  \
# 0           0       NaN                 NaN                   NaN
# 1           1       NaN                 NaN                   NaN
# 2           2  Standard                 NaN              Optional
# 3           3  Standard                 NaN                   NaN
# 4           4       NaN                 NaN                   NaN
#
#   AdaptiveDrivingBeam  AdaptiveHeadlights AdditionalErrorText  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# ...

# %%
gdf = gdf.drop(['Unnamed: 0'], axis=1)

# %%
cols = gdf.columns.tolist()
cols
# Out:
# ['ABS',
#  'ActiveSafetySysNote',
#  'AdaptiveCruiseControl',
#  'AdaptiveDrivingBeam',
#  'AdaptiveHeadlights',
#  'AdditionalErrorText',
#  'AirBagLocCurtain',
#  'AirBagLocFront',
#  'AirBagLocKnee',
#  'AirBagLocSeatCushion',
#  'AirBagLocSide',
#  'AutoReverseSystem',
#  'AutomaticPedestrianAlertingSound',
#  'AxleConfiguration',
#  'Axles',
#  'BasePrice',
#  'BatteryA',
#  'BatteryA_to',
#  'BatteryCells',
#  'BatteryInfo',
#  'BatteryKWh',
#  'BatteryKWh_to',
#  'BatteryModules',
#  'BatteryPacks',
#  'BatteryType',
#  'BatteryV',
#  'BatteryV_to',
#  'BedLengthIN',
#  'BedType',
#  'BlindSpotIntervention',
#  'BlindSpotMon',
#  'BodyCabType',
#  'BodyClass',
#  'BrakeSystemDesc',
#  'BrakeSystemType',
#  'BusFloorConfigType',
#  'BusLength',
#  'BusType',
#  'CAN_AACN',
#  'CIB',
#  'CashForClunkers',
#  'ChargerLevel',
#  'ChargerPowerKW',
#  'CoolingType',
#  'CurbWeightLB',
#  'CustomMotorcycleType',
#  'DaytimeRunningLight',
#  'DestinationMarket',
#  'DisplacementCC',
# ...

# %%
missings = gdf.isnull().sum().to_dict()
missings
# Out:
# {'ABS': 76273,
#  'ActiveSafetySysNote': 94477,
#  'AdaptiveCruiseControl': 92805,
#  'AdaptiveDrivingBeam': 93489,
#  'AdaptiveHeadlights': 101928,
#  'AdditionalErrorText': 101276,
#  'AirBagLocCurtain': 52021,
#  'AirBagLocFront': 11849,
#  'AirBagLocKnee': 79691,
#  'AirBagLocSeatCushion': 98939,
#  'AirBagLocSide': 21678,
#  'AutoReverseSystem': 80525,
#  'AutomaticPedestrianAlertingSound': 100574,
#  'AxleConfiguration': 101811,
#  'Axles': 80041,
#  'BasePrice': 85384,
#  'BatteryA': 101917,
#  'BatteryA_to': 101928,
#  'BatteryCells': 101926,
#  'BatteryInfo': 101591,
#  'BatteryKWh': 101789,
#  'BatteryKWh_to': 101859,
#  'BatteryModules': 101928,
#  'BatteryPacks': 101254,
#  'BatteryType': 101444,
#  'BatteryV': 101647,
#  'BatteryV_to': 101928,
#  'BedLengthIN': 101697,
#  'BedType': 59479,
#  'BlindSpotIntervention': 101910,
#  'BlindSpotMon': 89487,
#  'BodyCabType': 42522,
#  'BodyClass': 744,
#  'BrakeSystemDesc': 100475,
#  'BrakeSystemType': 62277,
# ...

# %%
no_make_df = gdf[gdf.Make == '']

# %%
make_df = gdf[(gdf.Make != '') & (gdf.Make.notna())]

# %%
top_makes = make_df.Make.value_counts().to_dict()
top_makes
# Out:
# {'FORD': 16293,
#  'CHEVROLET': 12116,
#  'TOYOTA': 9104,
#  'HONDA': 5852,
#  'NISSAN': 5196,
#  'JEEP': 4700,
#  'DODGE': 4253,
#  'GMC': 3814,
#  'BMW': 3651,
#  'HYUNDAI': 3023,
#  'SUBARU': 3004,
#  'MERCEDES-BENZ': 2981,
#  'RAM': 2952,
#  'KIA': 2510,
#  'VOLKSWAGEN': 2320,
#  'LEXUS': 2120,
#  'AUDI': 1879,
#  'CADILLAC': 1738,
#  'CHRYSLER': 1625,
#  'MAZDA': 1415,
#  'BUICK': 1344,
#  'ACURA': 1248,
#  'INFINITI': 1126,
#  'LINCOLN': 878,
#  'VOLVO': 799,
#  'LAND ROVER': 671,
#  'MITSUBISHI': 655,
#  'MINI': 634,
#  'PONTIAC': 422,
#  'PORSCHE': 399,
#  'JAGUAR': 319,
#  'SATURN': 243,
#  'MERCURY': 211,
#  'FIAT': 187,
#  'TESLA': 185,
#  'ALFA ROMEO': 144,
#  'HUMMER': 143,
#  'INTERNATIONAL': 129,
#  'FREIGHTLINER': 121,
#  'MASERATI': 116,
#  'GENESIS': 100,
#  'ISUZU': 91,
#  'SUZUKI': 86,
#  'SAAB': 72,
#  'OLDSMOBILE': 37,
#  'SMART': 31,
#  'KENWORTH': 28,
#  'IC BUS': 27,
#  'PETERBILT': 27,
#  'BENTLEY': 23,
#  'MITSUBISHI FUSO': 16,
#  'MACK': 16,
# ...

# %%
true_top_makes = {}
for x,y in top_makes.items():
    if y > 50:
        true_top_makes[x] = y
true_top_makes
# Out:
# {'FORD': 16293,
#  'CHEVROLET': 12116,
#  'TOYOTA': 9104,
#  'HONDA': 5852,
#  'NISSAN': 5196,
#  'JEEP': 4700,
#  'DODGE': 4253,
#  'GMC': 3814,
#  'BMW': 3651,
#  'HYUNDAI': 3023,
#  'SUBARU': 3004,
#  'MERCEDES-BENZ': 2981,
#  'RAM': 2952,
#  'KIA': 2510,
#  'VOLKSWAGEN': 2320,
#  'LEXUS': 2120,
#  'AUDI': 1879,
#  'CADILLAC': 1738,
#  'CHRYSLER': 1625,
#  'MAZDA': 1415,
#  'BUICK': 1344,
#  'ACURA': 1248,
#  'INFINITI': 1126,
#  'LINCOLN': 878,
#  'VOLVO': 799,
#  'LAND ROVER': 671,
#  'MITSUBISHI': 655,
#  'MINI': 634,
#  'PONTIAC': 422,
#  'PORSCHE': 399,
#  'JAGUAR': 319,
#  'SATURN': 243,
#  'MERCURY': 211,
#  'FIAT': 187,
#  'TESLA': 185,
#  'ALFA ROMEO': 144,
#  'HUMMER': 143,
#  'INTERNATIONAL': 129,
#  'FREIGHTLINER': 121,
#  'MASERATI': 116,
#  'GENESIS': 100,
#  'ISUZU': 91,
#  'SUZUKI': 86,
#  'SAAB': 72}

# %%
makers = list(true_top_makes.keys())

# %%
topdf = make_df[(make_df.Make.isin(makers)) & (make_df)]

# %%
topdf[topdf.Model.isnull()]#.value_counts()
# Out:
#         ABS ActiveSafetySysNote AdaptiveCruiseControl AdaptiveDrivingBeam  \
# 823     NaN                 NaN                   NaN                 NaN
# 1951    NaN                 NaN                   NaN                 NaN
# 4232    NaN                 NaN                   NaN                 NaN
# 4460    NaN                 NaN                   NaN                 NaN
# 4514    NaN                 NaN                   NaN                 NaN
# ...     ...                 ...                   ...                 ...
# 99595   NaN                 NaN                   NaN                 NaN
# 99942   NaN                 NaN                   NaN                 NaN
# 100367  NaN                 NaN                   NaN                 NaN
# 100566  NaN                 NaN                   NaN                 NaN
# 101663  NaN                 NaN                   NaN                 NaN
#
#         AdaptiveHeadlights                                AdditionalErrorText  \
# ...

# %%
make_df.Model.value_counts()
# Out:
# Model
# F-150                                      3957
# Silverado                                  3809
# Sierra                                     1744
# 1500                                       1732
# Wrangler                                   1608
#                                            ...
# 164                                           1
# Intrigue                                      1
# MBC Front Engine Commercial Bus Chassis       1
# 190                                           1
# LDJ MANUFACTURING, INC.                       1
# Name: count, Length: 1129, dtype: int64

# %%
type_counts = topdf.VehicleType.value_counts().to_dict()
type_counts
# Out:
# {'PASSENGER CAR': 39908,
#  'MULTIPURPOSE PASSENGER VEHICLE (MPV)': 37635,
#  'TRUCK': 21163,
#  'INCOMPLETE VEHICLE': 1947,
#  'BUS': 189,
#  'MOTORCYCLE': 27}

# %%
topdf2 = topdf[topdf.VehicleType.isin(['PASSENGER CAR', 'MULTIPURPOSE PASSENGER VEHICLE (MPV)', 'TRUCK', 'INCOMPLETE VEHICLE'])]
topdf2.VehicleType.value_counts().to_dict()
# Out:
# {'PASSENGER CAR': 39908,
#  'MULTIPURPOSE PASSENGER VEHICLE (MPV)': 37635,
#  'TRUCK': 21163,
#  'INCOMPLETE VEHICLE': 1947}

# %%
topdf2.Make[topdf2.VehicleType == 'INCOMPLETE VEHICLE'].value_counts()
# Out:
# Make
# FORD             971
# CHEVROLET        371
# GMC              150
# INTERNATIONAL    114
# RAM              102
# FREIGHTLINER      95
# ISUZU             71
# DODGE             54
# MERCEDES-BENZ     10
# CADILLAC           5
# LINCOLN            3
# BUICK              1
# Name: count, dtype: int64

# %%
topdf2.AdditionalErrorText.notna().sum()
# Out:
# 375

# %%
missingtrim = topdf2[(topdf2.Series.isnull()) & (topdf2.Series2.isnull()) & (topdf2.Trim.isnull()) & (topdf2.Trim2.isnull())]
missingtrim.isnull().sum().to_dict()
# Out:
# {'ABS': 9005,
#  'ActiveSafetySysNote': 10597,
#  'AdaptiveCruiseControl': 10807,
#  'AdaptiveDrivingBeam': 10596,
#  'AdaptiveHeadlights': 10931,
#  'AdditionalErrorText': 10781,
#  'AirBagLocCurtain': 5991,
#  'AirBagLocFront': 998,
#  'AirBagLocKnee': 10517,
#  'AirBagLocSeatCushion': 10887,
#  'AirBagLocSide': 2295,
#  'AutoReverseSystem': 9608,
#  'AutomaticPedestrianAlertingSound': 10807,
#  'AxleConfiguration': 10912,
#  'Axles': 9542,
#  'BasePrice': 10515,
#  'BatteryA': 10931,
#  'BatteryA_to': 10931,
#  'BatteryCells': 10931,
#  'BatteryInfo': 10870,
#  'BatteryKWh': 10872,
#  'BatteryKWh_to': 10904,
#  'BatteryModules': 10931,
#  'BatteryPacks': 10931,
#  'BatteryType': 10897,
#  'BatteryV': 10929,
#  'BatteryV_to': 10931,
#  'BedLengthIN': 10930,
#  'BedType': 5380,
#  'BlindSpotIntervention': 10931,
#  'BlindSpotMon': 10775,
#  'BodyCabType': 957,
#  'BodyClass': 111,
#  'BrakeSystemDesc': 10864,
#  'BrakeSystemType': 6554,
#  'BusFloorConfigType': 360,
# ...

# %%
missingtrim.ErrorCode.value_counts()
# Out:
# ErrorCode
# 0              10736
# 1                 30
# 1,400             24
# 1,3,14            23
# 0,14              11
# 1,5,14            10
# 1,5,14,400         9
# 4,14               8
# 1,14               8
# 1,3,14,400         7
# 6,14               7
# 8                  7
# 3,14               6
# 1,8                6
# 1,4,14,400         6
# 1,2,14             5
# 2,14               5
# 1,4,14             5
# 5,14               4
# 5,6,14             4
# 6,8                2
# 1,8,400            2
# 1,2,14,400         2
# 5,6,14,400         1
# 4,6,14             1
# 6,11,14            1
# 6,11,14,400        1
# Name: count, dtype: int64

# %%
missingtrimGoodVIN = missingtrim[missingtrim.ErrorCode == '0']
missingtrimBadVIN = missingtrim[missingtrim.ErrorCode != '0']
# Out:
#         ABS ActiveSafetySysNote AdaptiveCruiseControl AdaptiveDrivingBeam  \
# 202     NaN                 NaN                   NaN                 NaN
# 435     NaN                 NaN                   NaN                 NaN
# 823     NaN                 NaN                   NaN                 NaN
# 1269    NaN                 NaN                   NaN                 NaN
# 1513    NaN                 NaN                   NaN                 NaN
# ...     ...                 ...                   ...                 ...
# 100040  NaN                 NaN                   NaN                 NaN
# 100367  NaN                 NaN                   NaN                 NaN
# 101140  NaN                 NaN                   NaN                 NaN
# 101663  NaN                 NaN                   NaN                 NaN
# 101927  NaN                 NaN                   NaN                 NaN
#
#         AdaptiveHeadlights                                AdditionalErrorText  \
# ...

# %%
missingtrimBadVIN.Make.value_counts()
# Out:
# Make
# FORD             45
# NISSAN           17
# MITSUBISHI       14
# HONDA            13
# CADILLAC         11
# CHEVROLET        10
# BMW               8
# TOYOTA            7
# VOLKSWAGEN        6
# PORSCHE           6
# AUDI              6
# VOLVO             6
# LINCOLN           3
# SUBARU            3
# ISUZU             3
# MERCEDES-BENZ     3
# JAGUAR            3
# HYUNDAI           3
# INFINITI          3
# LAND ROVER        3
# GMC               2
# JEEP              2
# MERCURY           2
# CHRYSLER          2
# PONTIAC           2
# BUICK             2
# MASERATI          2
# FREIGHTLINER      2
# DODGE             1
# MAZDA             1
# SUZUKI            1
# LEXUS             1
# ACURA             1
# ALFA ROMEO        1
# Name: count, dtype: int64

# %%
topdf2.VIN[topdf2.VIN.str.contains('SAJGX274*VC')]# == 'SAJGX274*VC']
# Out:
#              ABS ActiveSafetySysNote AdaptiveCruiseControl  \
# 0            NaN                 NaN                   NaN
# 1            NaN                 NaN                   NaN
# 2       Standard                 NaN              Optional
# 3       Standard                 NaN                   NaN
# 4            NaN                 NaN                   NaN
# ...          ...                 ...                   ...
# 101922       NaN                 NaN                   NaN
# 101924       NaN                 NaN                   NaN
# 101925       NaN                 NaN                   NaN
# 101926       NaN                 NaN                   NaN
# 101927       NaN                 NaN                   NaN
#
#        AdaptiveDrivingBeam  AdaptiveHeadlights  \
# 0                      NaN                 NaN
# 1                      NaN                 NaN
# 2                      NaN                 NaN
# 3                      NaN                 NaN
# ...
