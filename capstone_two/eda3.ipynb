# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('merged_vins.csv')

# %%
df.shape
# Out:
# (93031, 125)

# %%
df.isnull().sum().to_dict()
# Out:
# {'ABS': 69089,
#  'ActiveSafetySysNote': 86030,
#  'AdaptiveCruiseControl': 84637,
#  'AdaptiveDrivingBeam': 85248,
#  'AirBagLocCurtain': 46318,
#  'AirBagLocFront': 9557,
#  'AirBagLocKnee': 72201,
#  'AirBagLocSeatCushion': 90286,
#  'AirBagLocSide': 18207,
#  'AutoReverseSystem': 73099,
#  'Axles': 72748,
#  'BasePrice': 77475,
#  'BedType': 53661,
#  'BlindSpotMon': 81543,
#  'BodyCabType': 38776,
#  'BodyClass': 1,
#  'BrakeSystemType': 57722,
#  'BusFloorConfigType': 0,
#  'BusType': 0,
#  'CAN_AACN': 81598,
#  'CIB': 82283,
#  'CoolingType': 83819,
#  'CustomMotorcycleType': 0,
#  'DaytimeRunningLight': 74088,
#  'DestinationMarket': 90149,
#  'DisplacementCC': 828,
#  'DisplacementCI': 828,
#  'DisplacementL': 828,
#  'Doors': 15505,
#  'DriveType': 26070,
#  'DynamicBrakeSupport': 72856,
#  'ESC': 71413,
#  'ElectrificationLevel': 90333,
#  'EngineConfiguration': 34450,
#  'EngineCycles': 87509,
#  'EngineCylinders': 8493,
#  'EngineHP': 42709,
#  'EngineHP_to': 86998,
# ...

# %%
#df['Year'] = pd.to_datetime(df['ModelYear'], format='%Y')
df['Year'] = df['ModelYear'].astype(int)
#plt.hist(df['Year'])
print(f"Maximum Year: {df.Year.max()} 
Minimum Year: {df.Year.min()}")
# Out:
# Maximum Year: 2025
# Minimum Year: 1981

# %%
df.drop('ModelYear', axis=1)
# Out:
#             ABS ActiveSafetySysNote AdaptiveCruiseControl AdaptiveDrivingBeam  \
# 0           NaN                 NaN                   NaN                 NaN
# 1           NaN                 NaN                   NaN                 NaN
# 2      Standard                 NaN              Optional                 NaN
# 3      Standard                 NaN                   NaN                 NaN
# 4           NaN                 NaN                   NaN                 NaN
# ...         ...                 ...                   ...                 ...
# 93026       NaN                 NaN                   NaN                 NaN
# 93027  Standard                 NaN                   NaN                 NaN
# 93028       NaN                 NaN                   NaN                 NaN
# 93029       NaN                 NaN                   NaN                 NaN
# 93030       NaN                 NaN                   NaN                 NaN
#
# ...

# %%
plt.hist(df['odometer'], range=[200000,500000])
# Out:
# (array([2270.,  931.,  337.,  142.,   54.,   32.,   15.,    7.,    6.,
#            4.]),
#  array([200000., 230000., 260000., 290000., 320000., 350000., 380000.,
#         410000., 440000., 470000., 500000.]),
#  <BarContainer object of 10 artists>)

# %%
print(f"Maximum odometer: {df.odometer.max()} 
Minimum odometer: {df.odometer.min()}")
# Out:
# Maximum odometer: 9999999.0
# Minimum odometer: 0.0

# %%
len(df[df['odometer'] < 5000])
# Out:
# 2427

# %%
len(df[df['odometer'] > 375000])
# Out:
# 111

# %%
df2 = df[(df.odometer <= 375000) & (df.odometer >= 5000)]

# %%
df2.odometer.describe()
# Out:
# count     90493.000000
# mean      93905.276088
# std       56595.317427
# min        5000.000000
# 25%       46092.000000
# 50%       90666.000000
# 75%      130955.000000
# max      372575.000000
# Name: odometer, dtype: float64

# %% [markdown]
# #### Checking columns for their % null values, and the diversity of information offered by each column.

# %%
cs = df2.columns.to_list()[0:100]

for each in cs:
    if each in ['VIN','VehicleDescriptor','ActiveSafetySysNote']:
        print('
')
    else:
        print(each)
        print(df2[each].value_counts().to_dict())
        print('nulls: ' + str(df2[each].isna().sum()/len(df2)))
        print('
')
# Out:
# ABS
# {'Standard': 22507, 'Optional': 18}
# nulls: 0.7510857193374073
#
#
#
#
# AdaptiveCruiseControl
# {'Optional': 4146, 'Standard': 3567, 'Not Available': 39}
# nulls: 0.9143359154851757
#
#
# AdaptiveDrivingBeam
# {'Standard': 3841, 'Optional': 3455, 'Not Available': 72}
# nulls: 0.9185793376283249
#
#
# AirBagLocCurtain
# {'All Rows': 20255, '1st and 2nd Rows': 18461, '1st Row (Driver and Passenger)': 4876, '1st and 2nd and 3rd Rows': 1814, 'Driver Seat Only': 5}
# nulls: 0.4981821798371145
#
#
# AirBagLocFront
# {'1st Row (Driver and Passenger)': 81046, 'Driver Seat Only': 145}
# nulls: 0.1027924811863901
#
#
# AirBagLocKnee
# {'1st Row (Driver and Passenger)': 11194, 'Driver Seat Only': 8159, 'Passenger Seat Only': 668}
# nulls: 0.7787563678958593
#
#
# AirBagLocSeatCushion
# {'Passenger Seat Only': 1497, '1st Row (Driver and Passenger)': 777, '1st and 2nd Rows': 273, 'Driver Seat Only': 79}
# nulls: 0.9709811808648183
#
#
# AirBagLocSide
# ...

# %%
# 10k nonnulls that are not 'optional' or 'Not Applicable/Available'
# partly safety, partly luxury 
useful_categoricals = ['GVWR', 'ABS', 'AirBagLocCurtain', 'AirBagLocSide', 'BodyClass', 'BrakeSystemType','Doors', 'DriveType', 
        'DynamicBrakeSupport', 'ESC', 'EngineConfiguration', 'EngineCylinders', 'FuelInjectionType','FuelTypePrimary', 'GVWR'
        'KeylessIgnition', 'Make', 'Model', 'Series','Series2','Trim','Trim2', 'RearVisibilitySystem', 'ValveTrainDesign', 'Turbo', 'ValveTrainDesign']

# 5k or more useful rows of information
# or barely varying information that may indicate luxury car or truck
less_useful_categoricals = ['AdaptiveCruiseControl', 'AdaptiveDrivingBeam', 'AirBagLocKnee', 'AutoReverseSystem','BlindSpotMon',
            'CAN_AACN', 'CIB', 'DayTimeRunningLight', 'EngineCycles', 'ForwardCollisionWarning', 'FuelTypeSecondary',
            'LaneDepartureWarning', 'LaneKeepSystem', 'LowerBeamHeadlampLightSource',  'PedestrianAutomaticEmergencyBraking',
            'Pretensioner', 'SeatRows', 'Seats', 'SemiautomaticHeadlampBeamSwitching', 'TractionControl', 'TransmissionSpeeds'
            'TransmissionStyle', 'WheelSizeFront', 'WheelSizeRear', 'Windows']

# tells you possible further information that could help identify more specific car features in future iterations
veh_indicators = ['Make', 'Model', 'Series','Series2','Trim','Trim2',
    'VehicleDescriptor', 'VehicleType']

#specific car information that doesn't differ much or is 95%+ nulls
mostly_useless = ['AirBagLocFront','AirBagLocSeatCushion', 'ParkAssist', 'RearCrossTrafficAlert', 'SeatBeltsAll', 
        'SteeringLocation', 'TPMS', 'WheelBaseShort', 'WheelBaseType', 'Wheels']

#pickup truck specifc
truck_info = ['BedType', 'BodyCabType']
                  
# absolutely useless information
# drop cols
useless= ['Axles', 'BusFloorConfigType', 'BusType', 'CoolingType', 'CustomMotorcycleType', 'DestinationMarket',
          'ErrorCode', 'ErrorText', 'MotorcycleSuspensionType','MotorcycleChassisType', 'TrailerBodyType', 'TrailerType']

# specific, robust information but very disorganized and highly variant
extras= ['ActiveSafetySysNote', 'Note', 'OtherEngineInfo', 'ElectrificationLevel']

extra_car_info = ['EngineManufacturer', 'EngineModel', 'Manufacturer', 'PlantCity', 'PlantCompanyName', 
    'PlantState', 'PlantCountry']
          
#linear regression
number_cols = ['BasePrice','DisplacementCC', 'EngineHP', 'Year', 'TopSpeedMPH']

redundant = ['DisplacementCI','DisplacementL', 'MakeID', 'ModelID', 'EngineHP_to','GVWR_to']
# displacementCI and displacementL are same as displacementCC
# MakeID and ModelID are same as Make and Model
# eletrification level is covered in fuel type
             
ids = ['VIN', 'id']

# %%
df3 = df2.drop(columns= useless + redundant, axis=1)

df3.shape
# Out:
# (90493, 108)

# %% [markdown]
# ### Craigslist Columns, not as reliable or consistent information aside from odometer.

# %%
cl_cols = ['id', 'url', 'region', 'region_url', 'price', 'year', 'manufacturer', 'model', 'condition', 
    'cylinders', 'fuel', 'odometer', 'title_status', 'transmission', 'drive', 'size', 'type', 'paint_color', 
    'image_url', 'description', 'county', 'state', 'lat', 'long', 'posting_date']

# %%
cl_cats = ['condition', 'transmission', 'drive', 'size', 'type', 'paint_color']

# %%
for each in cl_cats:
    print(each)
    print(df3[each].value_counts().to_dict())
    print('nulls: ' + str(df3[each].isna().sum()/len(df2)))
    print('
')
# Out:
# condition
# {'excellent': 24375, 'good': 20376, 'like new': 3270, 'fair': 529}
# nulls: 0.46349441393256935
#
#
# transmission
# {'automatic': 77273, 'other': 8774, 'manual': 3854}
# nulls: 0.00654194247068834
#
#
# drive
# {'4wd': 31740, 'fwd': 29138, 'rwd': 10195}
# nulls: 0.21460223442697224
#
#
# size
# {'full-size': 11967, 'mid-size': 6816, 'compact': 4140, 'sub-compact': 822}
# nulls: 0.7376040135701104
#
#
# type
# {'sedan': 22628, 'SUV': 21416, 'pickup': 8651, 'truck': 6504, 'other': 4574, 'hatchback': 3921, 'coupe': 3312, 'wagon': 3131, 'van': 1789, 'convertible': 1497, 'mini-van': 1286, 'offroad': 55, 'bus': 5}
# nulls: 0.12955698230802382
#
#
# paint_color
# {'white': 17518, 'black': 15729, 'silver': 11580, 'blue': 7621, 'red': 6729, 'grey': 6417, 'custom': 1698, 'green': 1485, 'brown': 1401, 'orange': 388, 'yellow': 327, 'purple': 162}
# nulls: 0.21480114483993237

# %%
cols = ['BasePrice', 'DisplacementCC', 'EngineHP','Year', 'TopSpeedMPH'] + ['price','odometer']

sns.heatmap(df3[cols].corr())
# Out:
# <Axes: >

# %% [markdown]
# #### Strong correlation between TopSpeedMPH and DisplacementCC, as well as between "Year" and "Odometer".
#
# #### Surprisingly, EngineHP does not correlate very strongly with TopSpeedMPH.
#
# #### BasePrice, with many missing values, forms a surprinsgly weak correlation with eventual list price, weaker than odometer, Year, and even engine displacement

# %% [markdown]
# #### While I do intend on finding MSRP to enhance the predictive power of the model, these categorical columns will have to do for determining car quality. They will be encoded later on in the next step.

# %%
features = ['DisplacementCC', 'EngineHP', 'Year', 'TopSpeedMPH', 'odometer']

# %%
def scatter(xcol,ycol,df):
    
        # Scatter plot
    plt.figure(figsize=(8, 6))  # Optional: Adjust the size of the plot

    plt.scatter(df[xcol], df[ycol], color='blue', marker='o', label='Data')

    # Add labels and title
    plt.xlabel(xcol)
    plt.ylabel(ycol)
    plt.title('Scatter Plot of ' + ycol + ' vs ' + xcol)

    # Add grid if desired
    plt.grid(True)

    # Add legend
    plt.legend()

    # Show plot
    plt.show()

# %%
for f in features:
    scatter(f,'price',df3)

# %%
df3[(df3['price'] > 120000) & (df3['odometer'] > 160000)][['Make','Model','price','condition','Year','odometer']].head()
# Out:
#        Make   Model   price condition  Year  odometer
# 25309  FORD  Escape  150000      good  2009  182415.0

# %%
df3.shape
# Out:
# (90493, 108)

# %%
print('Number of rows with DisplacementCC < 10000: ' + str(len(df3[(df3['DisplacementCC'] < 10000)])))
print('Number of rows with DisplacementCC null: ' + str(len(df3[(df3['DisplacementCC'].isnull())])))
print('Number of rows with EngineHP <= 700: ' + str(len(df3[df3['EngineHP'] <= 700])))
print('Number of rows with EngineHP null: ' + str(len(df3[df3['EngineHP'].isnull()])))
# Out:
# Number of rows with DisplacementCC < 10000: 89694
# Number of rows with DisplacementCC null: 784
# Number of rows with EngineHP <= 700: 48759
# Number of rows with EngineHP null: 41717

# %%
df4 = df3[((df3['EngineHP'].isnull()) | (df3['EngineHP'] <= 700))]
df4 = df4[(df4['DisplacementCC'].isnull() | (df4['DisplacementCC'] <= 10000))]

# %%
print('DisplacementCC max: ' + str(df4['DisplacementCC'].max()))
print('EngineHP max: ' + str(df4['EngineHP'].max()))
# Out:
# DisplacementCC max: 8685.14392
# EngineHP max: 662.0

# %% [markdown]
# #### Outliers of DisplacementCC greater than 10,000 and EngineHP greater than 700 removed.

# %%
df4.shape
# Out:
# (90461, 108)

# %%
from itertools import combinations
engine_ls = ['TopSpeedMPH', 'DisplacementCC', 'EngineHP', 'price']

engine_pairs = combinations(engine_ls, 2)

for i in list(engine_pairs):
    scatter(i[0],i[1],df4)

# %%
cols = ['BasePrice', 'DisplacementCC', 'EngineHP','Year', 'TopSpeedMPH'] + ['price','odometer']

print(df4[cols].corr())
# Out:
#                 BasePrice  DisplacementCC  EngineHP      Year  TopSpeedMPH  \
# BasePrice        1.000000        0.428656  0.682995  0.032248     0.179421
# DisplacementCC   0.428656        1.000000  0.771363 -0.147936    -0.236605
# EngineHP         0.682995        0.771363  1.000000  0.202572    -0.000044
# Year             0.032248       -0.147936  0.202572  1.000000     0.216705
# TopSpeedMPH      0.179421       -0.236605 -0.000044  0.216705     1.000000
# price            0.625395        0.400344  0.609971  0.550266    -0.008084
# odometer        -0.024426        0.178175 -0.092545 -0.634968    -0.198702
#
#                    price  odometer
# BasePrice       0.625395 -0.024426
# DisplacementCC  0.400344  0.178175
# EngineHP        0.609971 -0.092545
# Year            0.550266 -0.634968
# TopSpeedMPH    -0.008084 -0.198702
# price           1.000000 -0.538067
# odometer       -0.538067  1.000000

# %%
sns.heatmap(df4[cols].corr(), vmin=-1, cmap="PiYG")
# Out:
# <Axes: >

# %% [markdown]
# EngineHP has stronger correlation with eventual list price than any other feature. Surprising! It is likely the fact that EngineHP has ~50% missing values will affect the true strength of this feature. Year and Odometer have NO missing values and show a correlation of **0.55** (year/price corr) and and **-0.53** (odometer/price), which are strong. These features themselves are highly correlated with a score of **-0.63**, as expected. However, **DisplacementCC and EngineHP have the strongest correlation with 0.769**, even more than year and oodometer's score of -0.63, yet **DisplacementCC has 0.4 correlation with price while EngineHP has 0.612 correlation with price. Therefore, DisplacementCC will likely *not* be chosen in the eventual model.** TopSpeedMPH is not very useful, showing very weak correlation with price, and slight correlation with Year. It is likely that the feature of year and odometer will need to be counted as one feature, while **BasePrice** is able to be worked into the eventual model, showing a strong correlation with price of **.628**. It is a good idea to try to get an idea of which cars are luxury cars made with premium materials or big trucks which have a much higher MSRP. I am still working on inputting the base MSRP to the data, and other features such as EngineHP and the categorical data, could be scraped as well as this base MSRP. For the features above, once some tests were run to determine their viability, I would predict features chosen to be odometer, year, and EngineHP. It will be interesting to see how different features affect the depreciation of each vehicle and which feature strengths may change depending on other features of the vehicle. For example, convertibles likely do not hold their value as well as a truck, which provides utility in moving large objects. Categorical data will be very important compared to just Odometer and EngineHP, but MSRP can tell the story of these categorical features (luxury cars, extra safety features, premium options, or if truck).

# %%
# LIST OF CATEGORICAL DATA TO BE USED

cats = ['GVWR', 'ABS', 'AirBagLocCurtain', 'AirBagLocSide', 'BodyClass', 'BrakeSystemType','Doors', 'DriveType', 
        'DynamicBrakeSupport', 'ESC', 'EngineConfiguration', 'EngineCylinders', 'FuelInjectionType','FuelTypePrimary',
        'KeylessIgnition', 'RearVisibilitySystem', 'ValveTrainDesign', 'Turbo', 'ValveTrainDesign']

extra_cats = ['AdaptiveCruiseControl', 'AdaptiveDrivingBeam', 'AirBagLocKnee', 'AutoReverseSystem','BlindSpotMon',
            'CAN_AACN', 'CIB', 'EngineCycles', 'ForwardCollisionWarning', 'FuelTypeSecondary',
            'LaneDepartureWarning', 'LaneKeepSystem', 'LowerBeamHeadlampLightSource',  'PedestrianAutomaticEmergencyBraking',
            'Pretensioner', 'SeatRows', 'Seats', 'SemiautomaticHeadlampBeamSwitching', 'TractionControl', 'TransmissionSpeeds',
            'TransmissionStyle', 'WheelSizeFront', 'WheelSizeRear', 'Windows']

cl_cats = ['condition', 'transmission', 'drive', 'size', 'type', 'paint_color']

len(cl_cats + extra_cats + cats)
# Out:
# 49

# %%
import pandas as pd
import numpy as np

# %%
df7 = pd.read_csv('df7.csv')#, low_memory=False)

# %%
df7.VehicleType.value_counts(dropna=True)
# Out:
# VehicleType
# PASSENGER CAR                           36461
# MULTIPURPOSE PASSENGER VEHICLE (MPV)    34495
# TRUCK                                   19537
# Name: count, dtype: int64

# %%
df7.BodyClass.value_counts(dropna=False)
# Out:
# BodyClass
# Sport Utility Vehicle (SUV)/Multi-Purpose Vehicle (MPV)    30325
# Sedan/Saloon                                               25399
# Pickup                                                     18163
# Hatchback/Liftback/Notchback                                4545
# Coupe                                                       3445
# Minivan                                                     2473
# Convertible/Cabriolet                                       1704
# Crossover Utility Vehicle (CUV)                             1504
# Cargo Van                                                   1285
# Wagon                                                        956
# Van                                                          384
# Sport Utility Truck (SUT)                                    191
# Roadster                                                      83
# Truck-Tractor                                                 15
# ...

# %% [markdown]
# ### BodyClass is more descriptive than VehicleType, but many of them are too small # to be useful. Body Classes with < 300 rows will be removed as it is a small section of the data. In this case, 'Van' and everything above it will remain in the data.

# %%
body_ls = []
for k,v in df7.BodyClass.value_counts().to_dict().items():
    if v > 300:
        body_ls.append(k)
body_ls
# Out:
# ['Sport Utility Vehicle (SUV)/Multi-Purpose Vehicle (MPV)',
#  'Sedan/Saloon',
#  'Pickup',
#  'Hatchback/Liftback/Notchback',
#  'Coupe',
#  'Minivan',
#  'Convertible/Cabriolet',
#  'Crossover Utility Vehicle (CUV)',
#  'Cargo Van',
#  'Wagon',
#  'Van']

# %%
df8 = df7[df7.BodyClass.isin(body_ls)]

# %%
df8.BodyClass.value_counts(dropna=True)
# Out:
# BodyClass
# Sport Utility Vehicle (SUV)/Multi-Purpose Vehicle (MPV)    30325
# Sedan/Saloon                                               25399
# Pickup                                                     18163
# Hatchback/Liftback/Notchback                                4545
# Coupe                                                       3445
# Minivan                                                     2473
# Convertible/Cabriolet                                       1704
# Crossover Utility Vehicle (CUV)                             1504
# Cargo Van                                                   1285
# Wagon                                                        956
# Van                                                          384
# Name: count, dtype: int64

# %% [markdown]
# #### Vehicles without Turbo options have been returned as nulls. Fixing this by imputing it as a 'No'.

# %%
inds = df8[df8.Turbo.isnull()].index
inds
# Out:
# Index([    0,     1,     2,     3,     4,     5,     6,     7,     9,    10,
#        ...
#        90481, 90483, 90484, 90485, 90486, 90487, 90489, 90490, 90491, 90492],
#       dtype='int64', length=72749)

# %%
df8.loc[inds, 'Turbo'] = 'No'

# %% [markdown]
# ##### All Turbo Nulls imputed, but I would rather it be a '1' or '0' value.

# %%
df8.Turbo = df8.Turbo.replace({'Yes':1, 'No':0})

# %%
df8.Turbo.value_counts(dropna=True)
# Out:
# Turbo
# 0    81098
# 1     9085
# Name: count, dtype: int64

# %%
df8.isnull().sum().to_dict()
# Out:
# {'ABS': 67658,
#  'ActiveSafetySysNote': 83326,
#  'AdaptiveCruiseControl': 82431,
#  'AdaptiveDrivingBeam': 82815,
#  'AirBagLocCurtain': 44812,
#  'AirBagLocFront': 9141,
#  'AirBagLocKnee': 70193,
#  'AirBagLocSeatCushion': 87557,
#  'AirBagLocSide': 17555,
#  'AutoReverseSystem': 71591,
#  'BasePrice': 75315,
#  'BedType': 51967,
#  'BlindSpotMon': 79461,
#  'BodyCabType': 37529,
#  'BodyClass': 0,
#  'BrakeSystemType': 56038,
#  'CAN_AACN': 79531,
#  'CIB': 80180,
#  'DaytimeRunningLight': 72567,
#  'DisplacementCC': 759,
#  'Doors': 14932,
#  'DriveType': 6746,
#  'DynamicBrakeSupport': 71268,
#  'ESC': 69943,
#  'ElectrificationLevel': 87623,
#  'EngineConfiguration': 33452,
#  'EngineCycles': 84876,
#  'EngineCylinders': 3250,
#  'EngineHP': 41479,
#  'EngineHP_to': 84299,
#  'EngineManufacturer': 47188,
#  'EngineModel': 41886,
#  'ForwardCollisionWarning': 79247,
#  'FuelInjectionType': 66560,
#  'FuelTypePrimary': 3057,
#  'FuelTypeSecondary': 81468,
#  'GVWR': 896,
# ...

# %% [markdown]
# ##### About half of the null DisplacementCC values are from Electric Vehicles. Electric Vehicles are too different from Engines to create features for. Also, the number of rows are too small to be meaningfully analyzed.

# %%
df9 = df8[~df8['displ'].isnull()]
df9.displ.isnull().sum()
# Out:
# 0

# %% [markdown]
# #### All engine displacements are imputed and ready! Now, missing DriveType can be imputed based on the BodyClass/EngineCylinders combination with the thought process that bigger cars + bigger engines = 4WD. Most of the value counts confirmed this with a clear frontrunner in DriveType among the BodyClass/EngineCylinder combinations.

# %%
dc = {}
for each in body_ls:
    n_df = df8[df8.BodyClass == each]
    print(each)
    for cyl in [4.0,6.0,8.0]:
        n_df2 = n_df[n_df.EngineCylinders == cyl]
        print(cyl)
        print(n_df2.DriveType.value_counts(dropna=False))
        print('
')
        #dc[each] = n_df.DriveType.mode()[0]
# Out:
# Sport Utility Vehicle (SUV)/Multi-Purpose Vehicle (MPV)
# 4.0
# DriveType
# 4WD    3867
# AWD    2931
# FWD    2254
# 2WD    2053
# NaN     513
# RWD      98
# Name: count, dtype: int64
#
#
# 6.0
# DriveType
# 4WD    6594
# AWD    2884
# FWD    1625
# 2WD    1495
# NaN     612
# RWD     116
# Name: count, dtype: int64
#
#
# 8.0
# DriveType
# 4WD    2853
# 2WD     587
# AWD     309
# NaN     159
# RWD     140
# FWD       6
# Name: count, dtype: int64
#
#
# Sedan/Saloon
# 4.0
# DriveType
# FWD    7491
# 2WD    4030
# NaN    1937
# AWD    1245
# RWD     621
# 4WD     324
# Name: count, dtype: int64
#
#
# 6.0
# DriveType
# FWD    1981
# 2WD    1275
# RWD    1185
# AWD    1124
# NaN     774
# 4WD     568
# Name: count, dtype: int64
#
#
# 8.0
# DriveType
# RWD    743
# NaN    246
# AWD    219
# FWD    123
# 2WD    112
# 4WD     79
# Name: count, dtype: int64
#
#
# Pickup
# 4.0
# DriveType
# 2WD    377
# 4WD    213
# RWD      8
# NaN      7
# AWD      4
# Name: count, dtype: int64
#
#
# ...

# %%
dc
# Out:
# {'Sport Utility Vehicle (SUV)/Multi-Purpose Vehicle (MPV)': '4WD',
#  'Sedan/Saloon': 'FWD',
#  'Pickup': '4WD',
#  'Hatchback/Liftback/Notchback': 'FWD',
#  'Coupe': 'RWD',
#  'Minivan': 'FWD',
#  'Convertible/Cabriolet': 'RWD',
#  'Crossover Utility Vehicle (CUV)': '4WD',
#  'Cargo Van': '2WD',
#  'Wagon': 'FWD',
#  'Van': 'FWD'}

# %%
df8.DisplacementCC.value_counts(dropna=False).to_dict()
# Out:
# {2000.0: 8744,
#  3500.0: 7215,
#  3600.0: 7080,
#  2500.0: 6309,
#  2400.0: 4860,
#  5300.0: 3938,
#  5700.0: 3013,
#  3000.0: 2869,
#  4000.0: 2159,
#  1800.0: 2126,
#  6700.0: 2026,
#  1600.0: 1985,
#  1500.0: 1861,
#  3700.0: 1797,
#  1400.0: 1595,
#  6200.0: 1572,
#  5000.0: 1560,
#  3474.057568: 1299,
#  3456.0: 1288,
#  2359.737216: 1238,
#  6000.0: 1147,
#  3800.0: 1132,
#  2700.0: 1045,
#  4600.0: 1040,
#  5400.0: 1040,
#  1984.0: 1002,
#  6600.0: 981,
#  3300.0: 981,
#  1798.0: 934,
#  nan: 759,
#  1802.57704: 663,
#  2979.1682352: 651,
#  2300.0: 639,
#  1995.9443952: 617,
#  4700.0: 583,
#  2362.0: 569,
#  5600.0: 534,
#  4300.0: 499,
#  4800.0: 458,
#  6400.0: 417,
#  3200.0: 415,
#  1997.5831016: 376,
#  2356.0: 344,
#  4663.0: 343,
#  4200.0: 342,
#  2480.0: 337,
#  2200.0: 327,
#  2354.0: 325,
#  2995.5552992: 323,
#  3471.0: 263,
#  5900.0: 253,
#  2487.0: 253,
#  1491.222824: 229,
#  1597.73874: 213,
#  3400.0: 212,
#  4395.0105648: 203,
#  3900.0: 189,
# ...

# %% [markdown]
# ##### Some 'DisplacementCC' values are way too specific. Needs to be rounded to nearest integer. Additionally, I have found that the null engine displacements (n=759) were from electric cars (n=464).

# %%
df8['displ'] = df8[df8.DisplacementCC.notna()].round().DisplacementCC.astype(int)
len(df8[df8['displ'].isnull() & df8['ElectrificationLevel'].notna()])
# Out:
# C:\Users\pgrts\AppData\Local\Temp\ipykernel_48528\1534909331.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df8['displ'] = df8[df8.DisplacementCC.notna()].round().DisplacementCC.astype(int)
# 464

# %%
n_dt = df8[df8.DriveType.isnull()]

# %% [markdown]
# ## n_dt = Missing DriveType DataFrame

# %%
n_dt.Model.value_counts(dropna=False).to_dict()
# Out:
# {'Elantra': 134,
#  'Q5': 132,
#  'Odyssey': 112,
#  'Malibu': 110,
#  'Impala': 109,
#  'Jetta': 101,
#  'Fusion': 96,
#  'A6': 91,
#  'Camaro': 90,
#  'Optima': 86,
#  'Q7': 85,
#  'MDX': 85,
#  'Passat': 79,
#  'Corvette': 78,
#  'Mazda3': 73,
#  'Soul': 73,
#  'A5': 72,
#  'Tiguan': 69,
#  'Explorer': 65,
#  'Cayenne': 63,
#  'Escape': 57,
#  'S5': 51,
#  'CLA-Class': 49,
#  'Range Rover Sport': 49,
#  'GLE-Class': 49,
#  'Fiesta': 46,
#  'Forte': 46,
#  'TL': 45,
#  'Hardtop': 41,
#  'A3': 41,
#  'A4': 41,
#  'S-Class': 41,
#  'Transit Connect': 39,
#  'GLC-Class': 39,
#  'Range Rover': 38,
#  'Accent': 37,
#  '528i': 36,
#  'Veloster': 35,
#  'Sonic': 33,
#  'Atlas': 33,
#  'Beetle': 32,
#  'Countryman': 32,
#  'CLS-Class': 31,
#  'A7': 31,
#  'Silverado': 30,
#  'Transit': 30,
#  'A4 allroad': 29,
#  'A8': 27,
#  'X5': 27,
#  'Genesis': 26,
#  'ML-Class': 25,
#  'Mazda6': 25,
#  'Rio': 25,
#  'Range Rover Evoque': 25,
#  'S3': 24,
#  'Fit': 24,
#  'Impreza': 24,
#  'TSX': 23,
# ...

# %% [markdown]
# #### 6650 null DriveTypes. Not that many to look at the top Model values and process them individually. I have imputed the missing DriveType rows based on the DriveType values of the rest of the data who share attributes with the missing row, such as the Model and Year.
#
# #### An example of the below loop:
# #### use pd.notnull() to verify EngineDisplacement (displ), Cylinders, Trim, Year are not null and combine into a masked dataframe with ONLY cars with these features.
# #### For example if the row is a 2013 Chevrolet Malibu with engine displacement 2.5L and missing DriveType, return the value counts of DriveType for 2013 Chevrolet Malibu 2.5L engines. pd.not_null() is used to ensure the highest number of relevant features are used (ex: Trim) as about half of Trims are missing. The missing DriveType rows are processed in order of the highest number of rows represented by each Model. Imputation is done manually based on the class imbalance in the returned value_counts().

# %%
n_dt2 = n_dt[(n_dt['Model'] == 'A4')]


for idx, row in n_dt2.iterrows():
    
    maskls = []
    
    if pd.notnull(row['Model']):
        maskls.append(df9['Model'] == row['Model'])   
    if pd.notnull(row['Make']):
        maskls.append(df9['Make'] == row['Make'])   
    if pd.notnull(row['displ']):
        maskls.append(df9['displ'] == row['displ'])         
    if pd.notnull(row['Year']):
        maskls.append(df9['Year'] == row['Year'])         
    if pd.notnull(row['Trim']):
        maskls.append(df9['Trim'] == row['Trim'])
    if pd.notnull(row['EngineCylinders']):
        maskls.append(df9['EngineCylinders'] == row['EngineCylinders'])        
        
    combined_mask = reduce(lambda x, y: x & y, maskls)

    print(df9[combined_mask][['BodyClass', 'Year','DriveType','Series','displ','EngineCylinders']])
    print(df9[combined_mask][['BodyClass', 'Year','DriveType','Series','displ','EngineCylinders']]['DriveType'].value_counts(dropna=False))
    print('
')

# %%
n_dt[n_dt['Model'] == 'Civic'][['Make','Model','Series','Year','DriveType','Series','displ','EngineCylinders']].isnull().sum()
# Out:
# Make                 0
# Model                0
# Series              77
# Year                 0
# DriveType          215
# Series              77
# displ                0
# EngineCylinders      1
# dtype: int64

# %%
df9[df9.DriveType.isnull()][['Make','Model','Year','Trim','Series','VIN','displ','EngineCylinders','EngineHP']]
# Out:
#             Make      Model  Year      Trim                        Series  \
# 51          AUDI         Q5  2018       NaN            Q5 quattro Premium
# 56         ACURA        MDX  2013      Tech                           NaN
# 72         BUICK  Encore GX  2020    Select                           NaN
# 81          AUDI         Q5  2018       NaN            Q5 quattro Premium
# 83          AUDI         A6  2018       NaN  A6 2.0T quattro premium plus
# ...          ...        ...   ...       ...                           ...
# 90431  CHEVROLET  Silverado  2011  1500 LTZ                           NaN
# 90432  CHEVROLET      Cruze  2012       1LT                           NaN
# 90433  CHEVROLET     Malibu  2013       LTZ                           NaN
# 90434  CHEVROLET      Spark  2015       2LT                           NaN
# 90479       AUDI         Q7  2007       NaN                           NaN
#
#                      VIN   displ  EngineCylinders  EngineHP
# ...

# %%
df12 = df11.copy()

# %% [markdown]
# #### It became difficult to manually process those with low number of value counts (10 or less), so each model's mode was imputed as seen below.

# %%
mdlz = n_dt.Model.value_counts(dropna=False).to_dict()

# %%
ls = []
for k,v in mdlz.items():
    if (v < 11) & (v>1):
        ls.append(k)
ls
# Out:
# ['Boxster',
#  'SRX',
#  'M-Class',
#  'Malibu Limited',
#  'Dakota',
#  'Forester',
#  'JX35',
#  'Sedona',
#  'G70',
#  'X3',
#  'Titan',
#  '550i',
#  'Golf GTI',
#  'M5',
#  'Grand Prix',
#  'Stinger',
#  'Q8',
#  'Eos',
#  'SLK-Class',
#  'MKZ',
#  'Jetta SportWagen',
#  'Cooper Convertible',
#  'Renegade',
#  'Z4',
#  'Prius',
#  'Galant',
#  'Golf SportWagen',
#  'Golf R',
#  'Crown Victoria',
#  'Mazda2',
#  'Granturismo',
#  'Deville',
#  'RX',
#  '750Li / ALPINA B7',
#  'Azera',
#  'Genesis Coupe',
#  '750i / ALPINA B7',
#  'Envoy',
#  'Thunderbird',
#  'RS 5',
#  'Mirage',
#  '750i',
#  'Impala Limited',
#  'Sportage',
#  'RL',
#  'Savana',
#  'Fortwo',
#  'Stratus',
#  'Elantra GT',
#  '9-3',
#  'Pathfinder',
#  'Lancer Evolution',
#  'Sky',
#  'XF',
#  'LR2',
#  'Sable',
#  'Monte Carlo',
#  'TT',
#  '650i',
#  'Eclipse',
#  'Firebird',
#  'Silverado HD',
#  'Century',
#  'R8',
#  'Discovery',
#  'Stelvio',
#  'K900',
#  'BRZ',
#  'S6',
#  'Neon',
#  '530xi',
#  'M4',
# ...

# %%
for mdl in ls:
    mdl_df = df12[(df12['Model'] == mdl) & (df12.DriveType.isnull())]
    mode = df12[(df12['Model'] == mdl)]['DriveType'].dropna().mode()[0]
    

    print(mdl)
    print(mode)
        
    print(df12.loc[mdl_df.index, 'DriveType'])
    
    df12.loc[mdl_df.index, 'DriveType'] = mode
    
    print(df12.loc[mdl_df.index, 'DriveType'])
# Out:
# Boxster
# RWD
# 7113     NaN
# 7275     NaN
# 7302     NaN
# 9843     NaN
# 9979     NaN
# 11862    NaN
# 11868    NaN
# 15916    NaN
# 48739    NaN
# 54448    NaN
# Name: DriveType, dtype: object
# 7113     RWD
# 7275     RWD
# 7302     RWD
# 9843     RWD
# 9979     RWD
# 11862    RWD
# 11868    RWD
# 15916    RWD
# 48739    RWD
# 54448    RWD
# Name: DriveType, dtype: object
# SRX
# FWD
# 9222     NaN
# 21960    NaN
# 25159    NaN
# 33669    NaN
# 33893    NaN
# 48137    NaN
# 52713    NaN
# 74300    NaN
# 79525    NaN
# 79942    NaN
# Name: DriveType, dtype: object
# 9222     FWD
# 21960    FWD
# 25159    FWD
# 33669    FWD
# 33893    FWD
# 48137    FWD
# 52713    FWD
# 74300    FWD
# 79525    FWD
# 79942    FWD
# Name: DriveType, dtype: object
# M-Class
# AWD
# 9620     NaN
# 11418    NaN
# 13452    NaN
# 25238    NaN
# 28184    NaN
# 30040    NaN
# 48459    NaN
# 60369    NaN
# 65639    NaN
# 83178    NaN
# Name: DriveType, dtype: object
# 9620     AWD
# 11418    AWD
# ...

# %% [markdown]
# #### Drop the remaining 100 rows with DriveType Null.

# %%
df13 = df12[~df12.DriveType.isnull()]

# %% [markdown]
# ##### In this Case, Mercedes-Benz E-Class and C-Class models had an indicator of 4WD - a 4 in it's Series 'E500 4-MATIC'. These were imputed based on if '4 M' or '4' was found in the Series, as verified by a df.Series.unique() check.

# %%
df9[(df9['Model'] == 'E-Class') & (df9.Series.str.contains('E500 4-MATIC'))][['Series', 'Year','DriveType']]#.DriveType.value_counts(dropna=False)
# Out:
#              Series  Year DriveType
# 83354  E500 4-MATIC  2006       AWD

# %%
idx_42 = df9[(df9['Model'] == 'E-Class') & (df9.Series.str.contains('4 M'))].index#[['Series', 'Year','DriveType']]#.DriveType.value_counts(dropna=False)

# %%
e_df = df9[(df9['Model'] == 'E-Class')]
x_idx = e_df.loc[[x for x in e_df.index.tolist() if x not in idx_4 and x not in idx_42]].index
len(x_idx)
# Out:
# 470

# %%
c_cl_2_idx = df9[(df9['Model'] == 'C-Class') & (~df9.Series.str.contains('4', na=False))].index

# %% [markdown]
# ### Last missing features to impute:
# ##### Doors (n=14896)
# ##### EngineConfiguration (n=32682)
# ##### EngineCylinders(n=2800)
# ##### FuelTypePrimary (n=2815)
# ##### GVWR (n=855)

# %%
df13.isnull().sum().to_dict()
# Out:
# {'ABS': 67012,
#  'ActiveSafetySysNote': 82514,
#  'AdaptiveCruiseControl': 81677,
#  'AdaptiveDrivingBeam': 82065,
#  'AirBagLocCurtain': 44307,
#  'AirBagLocFront': 9021,
#  'AirBagLocKnee': 69630,
#  'AirBagLocSeatCushion': 86710,
#  'AirBagLocSide': 17307,
#  'AutoReverseSystem': 70918,
#  'BasePrice': 74626,
#  'BedType': 51825,
#  'BlindSpotMon': 78725,
#  'BodyCabType': 37398,
#  'BodyClass': 0,
#  'BrakeSystemType': 55212,
#  'CAN_AACN': 78726,
#  'CIB': 79445,
#  'DaytimeRunningLight': 71860,
#  'DisplacementCC': 0,
#  'Doors': 14896,
#  'DriveType': 0,
#  'DynamicBrakeSupport': 70595,
#  'ESC': 69284,
#  'ElectrificationLevel': 87242,
#  'EngineConfiguration': 32682,
#  'EngineCycles': 84031,
#  'EngineCylinders': 2800,
#  'EngineHP': 40862,
#  'EngineHP_to': 83466,
#  'EngineManufacturer': 46482,
#  'EngineModel': 41330,
#  'ForwardCollisionWarning': 78507,
#  'FuelInjectionType': 65746,
#  'FuelTypePrimary': 2815,
#  'FuelTypeSecondary': 80626,
#  'GVWR': 855,
# ...

# %% [markdown]
# ##### Similar to imputing DriveType, missing EngineCylinders was imputed based on the mode of each Model found. Engine Size (displ) was also used

# %%
for mod in ls:
    mdl_df = df14[df14['Model']==mod]
    mode = mdl_df['EngineCylinders'].dropna().mode()
    no_cyl_idx = no_cyl[no_cyl['Model']==mod].index
    
    if mode.empty:
        df14.loc[no_cyl_idx, 'EngineCylinders'] = 4.0
    else:
        df14.loc[no_cyl_idx, 'EngineCylinders'] = mode[0]

# %%
no_c = df14[df14.EngineCylinders.isnull()].index
len(no_c)
# Out:
# 0

# %% [markdown]
# ##### All clean! EngineCylinders imputed.

# %% [markdown]
# ##### FuelTypePrimary nulls are a bit trickier to impute for pickup trucks as many are diesel, Flex Fuel/Ethanol, and there is only come correlations between engine size and FuelType, as I have scaped and compiled separate datasets I have referenced, which include the Engine Size (displ) and Fuel Type of every Model, Trim and Year of many Pickup Trucks such as the GMC Sierra and Chevrolet Silverado.

# %%
df15[df15.FuelTypePrimary.isnull()]['Model'].value_counts().to_dict()
# Out:
# {'Outback': 216,
#  'Legacy': 189,
#  'Escalade': 115,
#  'Mazda6': 90,
#  'Corvette': 80,
#  'CX-9': 64,
#  'LeSabre': 47,
#  'Yukon': 46,
#  'Tahoe': 45,
#  '9-3': 33,
#  'B9 Tribeca': 33,
#  'Yukon XL': 29,
#  'Sorento': 29,
#  'Impala': 29,
#  'Camaro': 28,
#  'Scion FR-S': 28,
#  'Century': 26,
#  'MX-5': 26,
#  'Suburban': 25,
#  'SX4': 25,
#  'Vue': 24,
#  'Mazda2': 23,
#  'Firebird': 21,
#  'Mazda5': 21,
#  'Torrent': 19,
#  'CX-5': 18,
#  'HHR': 17,
#  'Discovery': 17,
#  'Colorado': 17,
#  'CLA-Class': 15,
#  'Lancer': 15,
#  'Vibe': 14,
#  'X3': 14,
#  'S-Type': 13,
#  'Freestar': 13,
#  'Monte Carlo': 13,
#  'Range Rover': 13,
#  'XK8': 13,
#  'Express': 12,
#  'Bonneville': 11,
#  'S-10 Pickup': 11,
#  'X-Type': 11,
#  'XK': 10,
#  'Grand Vitara': 9,
#  'Blazer': 8,
#  'Grand Prix': 8,
#  'XL7': 7,
#  '9-5': 7,
#  'Park Avenue': 7,
#  'BRZ': 7,
#  'GMT-400': 7,
#  'Aveo': 7,
#  'CTS': 6,
#  'XJ': 6,
#  'B-Series': 6,
#  'Sonoma': 6,
#  'Eclipse': 6,
#  '300': 5,
# ...

# %%
Silverado = df15[df15.Model == 'Silverado']

# %%
Silverado[['FuelTypePrimary','displ','EngineCylinders']].value_counts(dropna=False)
# Out:
# FuelTypePrimary              displ   EngineCylinders
# Gasoline                     5300.0  8.0                1438
# Diesel                       6600.0  8.0                 469
# Flexible Fuel Vehicle (FFV)  5300.0  8.0                 392
# Gasoline                     6000.0  8.0                 374
# Flexible Fuel Vehicle (FFV)  4300.0  6.0                 258
# Gasoline                     4800.0  8.0                 111
# NaN                          5300.0  8.0                  84
# Gasoline                     6200.0  8.0                  57
# NaN                          4800.0  8.0                  52
# Gasoline                     2200.0  4.0                  29
#                              2700.0  4.0                  28
#                              2400.0  4.0                  14
# Flexible Fuel Vehicle (FFV)  4800.0  8.0                  13
# NaN                          6600.0  8.0                  12
# Flexible Fuel Vehicle (FFV)  6200.0  8.0                  12
# ...

# %%
Silverado[Silverado['displ'] == 4300.0][['ModelYear', 'FuelTypePrimary','EngineCylinders','Series']].value_counts(dropna=False)
# Out:
# ModelYear  FuelTypePrimary              EngineCylinders  Series
# 2014.0     Flexible Fuel Vehicle (FFV)  6.0              1500              51
# 2015.0     Flexible Fuel Vehicle (FFV)  6.0              1500              46
# 2016.0     Flexible Fuel Vehicle (FFV)  6.0              1500              29
# 2017.0     Flexible Fuel Vehicle (FFV)  6.0              1500              26
# 2018.0     Flexible Fuel Vehicle (FFV)  6.0              1500              19
# 2013.0     Flexible Fuel Vehicle (FFV)  6.0              1500              15
# 2019.0     Flexible Fuel Vehicle (FFV)  6.0              1500              13
# 2020.0     Flexible Fuel Vehicle (FFV)  6.0              1500              10
# 2008.0     Flexible Fuel Vehicle (FFV)  6.0              1/2 Ton            9
# 2012.0     Flexible Fuel Vehicle (FFV)  6.0              NaN                8
# 2009.0     Flexible Fuel Vehicle (FFV)  6.0              1/2 Ton            7
# ...

# %%
Silverado[(Silverado['displ'] == 5300.0)& (Silverado.ModelYear.isin([2004,2005]))].index#[['FuelTypePrimary','EngineCylinders','Trim']].value_counts(dropna=False)
# Out:
# Index([ 2835,  5088,  5794,  7555,  7966,  7982,  8004, 10506, 10896, 11511,
#        11916, 12947, 15408, 16800, 19188, 22362, 22606, 26542, 27594, 28354,
#        30453, 30454, 32917, 34793, 35412, 36520, 36883, 38011, 39551, 39693,
#        41686, 42146, 42254, 42474, 42647, 42973, 43080, 43140, 43155, 43561,
#        45985, 50275, 50340, 52500, 52628, 53140, 53810, 59297, 59928, 60293,
#        62986, 64888, 65028, 66479, 66869, 67084, 69740, 72494, 72529, 72607,
#        73336, 73734, 73922, 74129, 74515, 74561, 75529, 76271, 81525, 82434,
#        82446, 83949, 85597, 87644, 87645, 87666],
#       dtype='int64')

# %%
Silverado[(Silverado['displ'] == 5300.0)& (Silverado.Trim.isin(['LS'])) & (Silverado.ModelYear == 2008.0)].index#[['FuelTypePrimary','Trim','ModelYear']].value_counts(dropna=False)
# Out:
# Index([ 1646,  2185, 13489, 16842, 18560, 18807, 21719, 22571, 25060, 26114,
#        26129, 30344, 31318, 32074, 33617, 34816, 35173, 35288, 35675, 36606,
#        37881, 37931, 38643, 38805, 39908, 40341, 41199, 41244, 41996, 42887,
#        43084, 43399, 43874, 47489, 49777, 50129, 50247, 50414, 50463, 51067,
#        51074, 52858, 57721, 59552, 62753, 63100, 66109, 66409, 66853, 67127,
#        67355, 67552, 68756, 70798, 73858, 74112, 75421, 75606, 76123, 76322,
#        77295, 77403, 79612, 83180, 83200, 83215, 85321, 85584, 88078],
#       dtype='int64')

# %%
Silverado[(Silverado.displ == 4800.0) & (Silverado.ModelYear.isin([2010,2011,2012,2013,2014]))][['EngineCylinders','FuelTypePrimary']].value_counts(dropna=False)
# Out:
# EngineCylinders  FuelTypePrimary
# 8.0              Gasoline                       73
#                  Flexible Fuel Vehicle (FFV)    13
# Name: count, dtype: int64

# %%
Outback = df15[df15.Model == 'Outback']

# %%
Outback[['displ', 'Turbo', 'EngineCylinders','FuelTypePrimary','ModelYear']].value_counts(dropna=False)
# Out:
# displ   Turbo  EngineCylinders  FuelTypePrimary  ModelYear
# 2500.0  0      4.0              Gasoline         2018.0       63
#                                                  2019.0       57
#                                                  2017.0       53
#                                 NaN              2011.0       38
#                                 Gasoline         2013.0       37
#                                                  2014.0       34
#                                                  2015.0       34
#                                                  2016.0       32
#                                 NaN              2008.0       28
#                                 Gasoline         2005.0       26
#                                                  2006.0       25
#                                 NaN              2007.0       24
#                                                  2014.0       20
#                                 Gasoline         2020.0       20
# ...

# %% [markdown]
# #### Diesel engine options within the same Model frequently involved a engine size (displ) change, but the API did not use this in it's VIN reports. Flex Fuel may have been overlooked for some imputations, but Diesel was not.
#
#
# #### Eventually, after processing each Model of high value counts, again, the mode ('Gasoline') was imputed in the remaining 1872 rows.

# %%
n_fl = df15[df15['FuelTypePrimary'].isnull()]
n_fl
# Out:
#        ABS ActiveSafetySysNote AdaptiveCruiseControl AdaptiveDrivingBeam  \
# 142    NaN                 NaN                   NaN                 NaN
# 161    NaN                 NaN                   NaN                 NaN
# 237    NaN                 NaN                   NaN                 NaN
# 292    NaN                 NaN                   NaN                 NaN
# 336    NaN                 NaN                   NaN                 NaN
# ...    ...                 ...                   ...                 ...
# 88993  NaN                 NaN                   NaN                 NaN
# 89215  NaN                 NaN                   NaN                 NaN
# 89304  NaN                 NaN                   NaN                 NaN
# 89397  NaN                 NaN                   NaN                 NaN
# 89421  NaN                 NaN                   NaN                 NaN
#
#        AirBagLocCurtain                  AirBagLocFront AirBagLocKnee  \
# ...

# %%
df15.loc[n_fl.index, 'FuelTypePrimary'] = 'Gasoline'

# %% [raw]
# Most rows with missing 'Door' values were pickup trucks and some vans. After doing some research, I found pickup trucks only had 4 doors if there was an extended cab or more. Therefore, Missing Doors values were imputed as 2 if BodyCabType == 'Regular' and 4 if not.

# %%
df15[df15['Doors'].isnull()].Model.value_counts(dropna=False).to_dict()
# Out:
# {'F-150': 3699,
#  '1500': 1590,
#  'F-250': 1282,
#  'F-350': 886,
#  'Ram': 821,
#  'Tacoma': 695,
#  'Tundra': 608,
#  '2500': 598,
#  'Silverado': 412,
#  'Transit': 324,
#  'Titan': 279,
#  'Frontier': 254,
#  '3500': 249,
#  'Transit Connect': 226,
#  'Sierra': 201,
#  'Ranger': 144,
#  'Prius': 127,
#  'Express': 127,
#  'E-250': 110,
#  'Dakota': 108,
#  'Yukon XL': 105,
#  'Suburban': 98,
#  'E-150': 89,
#  'Escalade': 86,
#  'Caravan/Grand Caravan': 70,
#  'XV CrossTrek': 70,
#  'Forester': 64,
#  'ProMaster 1500': 62,
#  'E-350': 58,
#  'F-450': 57,
#  'Savana': 56,
#  'Promaster City': 55,
#  'PT Cruiser': 53,
#  'Journey': 53,
#  'Ridgeline': 53,
#  'Compass': 51,
#  'Soul': 43,
#  'ProMaster 2500': 42,
#  'Sportage': 40,
#  'NV200': 39,
#  'XT4': 39,
#  'Colorado': 36,
#  'Sedona': 35,
#  'NV': 33,
#  'Tahoe': 30,
#  'Sprinter': 25,
#  'Yukon': 25,
#  'Crosstrek': 24,
#  'GMT-400': 24,
#  'City Express': 23,
#  'Pacifica': 22,
#  'S-10 Pickup': 22,
#  'Trax': 22,
# ...

# %%
silv_no = Silverado[Silverado['FuelTypePrimary'].isnull()]

# %% [raw]
# Initially EngineConfiguration was going to be ignored as a feature. However, it showed high correlation with 'Convertible" BodyClass which incidentally had errors that were above average so in an effort to improve the model, it was included as a feature and needed imputation. Each missing value was imputed from the car model's EngineConfiguration mode, and if there was too few values in the data, it's EngineCylinders was imputed as a map:
#
# 4.0 = 'In-Line',
# 6.0, 8.0, 10.0, 12.0 = 'V-Shaped',
# Cylinders < 4.0 = 'Horizontally opposed (boxer)',
# W Shaped was replaced as V-Shaped as it was too much of a minority within the data.

# %%
df15[['EngineConfiguration']].value_counts(dropna=False)
# Out:
# EngineConfiguration
# V-Shaped                        34587
# NaN                             32682
# In-Line                         21674
# Horizontally opposed (boxer)      375
# W Shaped                           16
# Name: count, dtype: int64

# %% [raw]
# The vehicles with 'GVWR' missing were those that were generally assumed to be below 6000LB as they were almost all Sedans, Coupes, and Convertibles. Coincidentally, that is the Mode of the column. Therefore, they were imputed with 'Class 1: 6000LB or less' as most vehicles have this rating. I believe these ones are missing because depending on Trim, DisplacementCC, or EngineCylinders, they may change between a more specific weight class (ex: 1A: 5000-6000LB or 1B: 4000-5000LB. However, it was too difficult to say and since most of the data lumps the vehicles together in a 6000LB or less category, it made the most sense as the imputation for the 855 missing rows.

# %%
df15[df15['GVWR'].isnull()][['Make', 'Model', 'Year']].value_counts().to_dict()
# Out:
# {('CHEVROLET', 'Cruze Limited', 2016): 77,
#  ('HYUNDAI', 'Veloster', 2013): 37,
#  ('CHEVROLET', 'Malibu Limited', 2016): 36,
#  ('GENESIS', 'G80', 2018): 34,
#  ('HYUNDAI', 'Veloster', 2016): 34,
#  ('CHEVROLET', 'Impala Limited', 2014): 33,
#  ('MERCEDES-BENZ', 'S-Class', 2015): 26,
#  ('HYUNDAI', 'Veloster', 2012): 25,
#  ('HYUNDAI', 'Veloster', 2015): 19,
#  ('MERCEDES-BENZ', 'S-Class', 2007): 19,
#  ('MERCEDES-BENZ', 'S-Class', 2008): 18,
#  ('GENESIS', 'G80', 2017): 18,
#  ('HYUNDAI', 'Veloster', 2017): 18,
#  ('INFINITI', 'QX30', 2018): 15,
#  ('MERCEDES-BENZ', 'S-Class', 2013): 15,
#  ('MERCEDES-BENZ', 'S-Class', 2017): 13,
#  ('MERCEDES-BENZ', 'S-Class', 2012): 13,
#  ('CHEVROLET', 'Impala Limited', 2015): 13,
#  ('MERCEDES-BENZ', 'S-Class', 2010): 12,
#  ('MERCEDES-BENZ', 'S-Class', 2018): 12,
#  ('MERCEDES-BENZ', 'S-Class', 2014): 12,
#  ('INFINITI', 'QX30', 2017): 9,
#  ('MERCEDES-BENZ', 'S-Class', 2006): 9,
#  ('HYUNDAI', 'Veloster N', 2020): 7,
# ...

# %% [raw]
# The craigslist inputted data field, 'fuel' can be referenced for those that do not have FuelTypePrimary, but it is not a totally reliable source. It turns out 3723 diesel trucks were correctly inputted by craigslist sellers as 'diesel' but 120 were inputted as Gasoline and even 1 as electric. Still not a bad job by user inputted data.

# %%
df15[df15.fuel == 'diesel'][['FuelTypePrimary']].value_counts().to_dict()
# Out:
# {('Diesel',): 3723, ('Gasoline',): 120, ('Electric',): 1}

# %%
df16 = df15.copy()

# %%
df16[(df16.Doors.isnull()) & (df16.Model.isin(['Tacoma']))].BodyCabType.value_counts(dropna=False)
# Out:
# BodyCabType
# Extra/Super/Quad/Double/King/Extended    586
# NaN                                       61
# Regular                                   48
# Name: count, dtype: int64

# %%
df16[(df16.Doors.isnull()) & (df16.Model.isin(['Tundra']))].BodyCabType.value_counts(dropna=False)
# Out:
# BodyCabType
# Extra/Super/Quad/Double/King/Extended    306
# Crew/Super Crew/Crew Max                 273
# NaN                                       15
# Regular                                   14
# Name: count, dtype: int64

# %% [markdown]
# ##### Doors imputation with BodyCabType Below.

# %%
df_reg.index
# Out:
# Index([   19,    23,    27,    62,   229,   306,   318,   324,   340,   453,
#        ...
#        87706, 87821, 88017, 88041, 88043, 88044, 88076, 88493, 88494, 89216],
#       dtype='int64', length=524)

# %%
df_not_reg.index
# Out:
# Index([   15,    18,    20,    25,    41,    44,    59,    87,   132,   191,
#        ...
#        89297, 89298, 89299, 89300, 89301, 89302, 89305, 89311, 89327, 89328],
#       dtype='int64', length=8963)

# %%
df_reg = df16[(df16.Doors.isnull()) & (df16.BodyCabType == 'Regular')]
df_not_reg = df16[(df16.Doors.isnull()) & (df16.BodyCabType != 'Regular')]

# %%
df16.loc[df_not_reg.index, 'Doors'] = 4.0
df16.loc[df_reg.index, 'Doors'] = 2.0

# %%
df16.isnull().sum().to_dict()
# Out:
# {'ABS': 67012,
#  'ActiveSafetySysNote': 82514,
#  'AdaptiveCruiseControl': 81677,
#  'AdaptiveDrivingBeam': 82065,
#  'AirBagLocCurtain': 44307,
#  'AirBagLocFront': 9021,
#  'AirBagLocKnee': 69630,
#  'AirBagLocSeatCushion': 86710,
#  'AirBagLocSide': 17307,
#  'AutoReverseSystem': 70918,
#  'BasePrice': 74626,
#  'BedType': 51825,
#  'BlindSpotMon': 78725,
#  'BodyCabType': 37398,
#  'BodyClass': 0,
#  'BrakeSystemType': 55212,
#  'CAN_AACN': 78726,
#  'CIB': 79445,
#  'DaytimeRunningLight': 71860,
#  'DisplacementCC': 0,
#  'Doors': 0,
#  'DriveType': 0,
#  'DynamicBrakeSupport': 70595,
#  'ESC': 69284,
#  'ElectrificationLevel': 87242,
#  'EngineConfiguration': 32682,
#  'EngineCycles': 84031,
#  'EngineCylinders': 0,
#  'EngineHP': 40862,
#  'EngineHP_to': 83466,
#  'EngineManufacturer': 46482,
#  'EngineModel': 41330,
#  'ForwardCollisionWarning': 78507,
#  'FuelInjectionType': 65746,
#  'FuelTypePrimary': 0,
#  'FuelTypeSecondary': 80626,
#  'GVWR': 1,
#  'GVWR_to': 54799,
# ...

# %% [raw]
# The only vehicles with cabs are pickup trucks so therefore the 37,398 missing rows are misleading, most are simply 'Not Applicable'.

# %%
df16[(df16['BodyClass'] == 'Pickup') & df16['BodyCabType'].isnull()].Model.value_counts()
# Out:
# Model
# Silverado              755
# Ram                    445
# Sierra                 265
# Tacoma                  62
# Colorado                60
# Ridgeline               46
# Explorer Sport Trac     46
# Dakota                  32
# GMT-400                 27
# Canyon                  23
# S-10 Pickup             20
# Ranger                  17
# Tundra                  15
# C/K Pickup              13
# El Camino                8
# Titan                    7
# Pick-Up                  7
# Sonoma                   5
# SSR                      5
# Escalade                 5
# D-Series                 4
# Pickup                   3
# Comanche                 2
# Raider                   2
# F-150                    2
# Caballero                2
# B-Series                 2
# W-Series                 1
# H3T                      1
# T100                     1
# 2500                     1
# Military Truck           1
# S15 Pickup               1
# Name: count, dtype: int64

# %% [raw]
# As you can see above, only ~1300 rows have missing BodyCabType. Doors was selected as the imputation, following the same logic above that 2 Doors = Regular Cab, 4 Doors = Extended and above.

# %%
df17 = df16.copy()

# %% [raw]
# There isn't really a great way to impute the 10k missing 'paint_color' rows. I have chosen to use the mode based on unique Model + Year combinations as it does not affect the representation of each color within the data and there may be correlation between Model Years and the colors produced (ex: Red Sports Car).

# %%
dc = {}

for k in df17[df17.paint_color.isnull()][['Model','Year']].value_counts().to_dict().keys():
    
    ides = df17[(df17.Model == k[0]) & (df17.Year == k[1]) & df17.paint_color.isnull()].index
    mode = df17[(df17.Model == k[0]) & (df17.Year == k[1])]['paint_color'].mode()
    
    if mode.empty:
        mode2 = df17[(df17.Model == k[0])]['paint_color'].mode()
        if mode2.empty:
            print(k[0])
        else:
            df17.loc[ides, 'paint_color'] = mode2[0]            
    else:
        df17.loc[ides, 'paint_color'] = mode[0]
# Out:
# 740 Series
# G20
# DB11
# Cressida
# 190
# 335is
# V90
# Vandura
# Aurora
# Bentayga
# Cabrio
# Ghost
# Karma
# LW300
# S60 Cross Country

# %%
df17.paint_color.value_counts()
# Out:
# paint_color
# white     23802
# black     21452
# silver    13833
# blue       8580
# red        7280
# grey       7098
# custom     1752
# green      1544
# brown      1421
# orange      383
# yellow      330
# purple      161
# Name: count, dtype: int64

# %%
df_new.isnull().sum()
# Out:
# Turbo              0
# BodyClass          0
# FuelTypePrimary    0
# EngineCylinders    0
# DriveType          0
# GVWR               0
# Doors              0
# paint_color        0
# odometer           0
# ModelYear          0
# displ              0
# price              0
# VehicleType        0
# dtype: int64

# %% [raw]
# Imputations complete!
